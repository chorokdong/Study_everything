# %%
# !pip install konlpy
# !pip install sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.9/dist-packages (2.2.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (0.14.1+cu116)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.2.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.13.1+cu116)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (4.26.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (0.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (0.1.97)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (3.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.25.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)

# %%
# !pip install konlpy

from konlpy.tag import Mecab
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab/
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 115 (delta 11), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (115/115), 1.27 MiB | 4.09 MiB/s, done.
# Resolving deltas: 100% (50/50), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: konlpy in /usr/local/lib/python3.9/dist-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (4.9.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.22.4)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from konlpy) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from JPype1>=0.7.0->konlpy) (23.0)
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-03-13 07:31:24--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22e9:9f55, 2406:da00:ff00::22c0:3470, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNATRKUZPE&Signature=8aHhQUXyrF2%2B%2Beq8yGwzFjPjhzQ%3D&x-amz-security-token=FwoGZXIvYXdzEBEaDMkGjVnd40MayQv8cyK%2BAW8yv7PrAmNJ1m%2F7Yp6QvBGwYgWa%2BN32vhc02g8MupmTTRtM6KNQVA9Lim78X1MWUqL0MInR3%2F8mpx%2FN82l2iMrcKISD%2FuO51Q1lRgPa75UqlOK5Fkxuz1ytFG04eUDAA%2BT%2Fh7QkGA2Wt1zsmDKGDhrqh%2BOXb6uwppeCudu3EO8vZmwGUKG4B6vi%2Fp2ZEoyJU%2FBRn4pc%2B%2BimDNn1Tg9HCKPyKJW%2BJ4cwqhL4JemM4dPSC4wg7URznWi2Y93oMzAo55u7oAYyLfGtBzaR7Pur%2B5eFQpMvZKy%2BdsgKEf%2Fmjg9RMypxVbeQrU38Y67U4LUZ%2FpkAGA%3D%3D&Expires=1678693615 [following]
# --2023-03-13 07:31:24--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNATRKUZPE&Signature=8aHhQUXyrF2%2B%2Beq8yGwzFjPjhzQ%3D&x-amz-security-token=FwoGZXIvYXdzEBEaDMkGjVnd40MayQv8cyK%2BAW8yv7PrAmNJ1m%2F7Yp6QvBGwYgWa%2BN32vhc02g8MupmTTRtM6KNQVA9Lim78X1MWUqL0MInR3%2F8mpx%2FN82l2iMrcKISD%2FuO51Q1lRgPa75UqlOK5Fkxuz1ytFG04eUDAA%2BT%2Fh7QkGA2Wt1zsmDKGDhrqh%2BOXb6uwppeCudu3EO8vZmwGUKG4B6vi%2Fp2ZEoyJU%2FBRn4pc%2B%2BimDNn1Tg9HCKPyKJW%2BJ4cwqhL4JemM4dPSC4wg7URznWi2Y93oMzAo55u7oAYyLfGtBzaR7Pur%2B5eFQpMvZKy%2BdsgKEf%2Fmjg9RMypxVbeQrU38Y67U4LUZ%2FpkAGA%3D%3D&Expires=1678693615
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.241.60, 54.231.195.137, 52.216.138.35, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.241.60|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  3.70MB/s    in 0.4s
#
# 2023-03-13 07:31:25 (3.70 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2023-03-13 07:33:22--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22e9:9f55, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNDQOYMLX4&Signature=X8Vxx%2FPDxQxqAiBk1ba5a5eHWUQ%3D&x-amz-security-token=FwoGZXIvYXdzEBEaDGWLHGj7QGBpt785WCK%2BAcK9cWzC4LDq1YoeaDEnysirAHuvwfS2GrjKLWtEIzVz3zbHUAhPm4kx5bEN374CW3cW48SWLhBAf4iC6nH8PpVWNVzZpIg8AuQSpFBD8LeVSFnHkin5Yk%2FS3IPN45D77ggvOJczAVLHFiEf7ek9CnxTD1MF%2BZbuAkAJiERBN1DNcD7wWaKKw%2FpTZ%2BJMeacu8kSM%2FsgOB4TFp22jGSgSnojOLj8Ms7ciW4LRfyGJv2zFrzbk01vEFPffAtDoO5Yo4Jy7oAYyLaCgZSXgWk04uGUxhH%2BI2XCRpIaVbDP5UBhgQZaRmEa2XNl2z9lgRISFUrhnKg%3D%3D&Expires=1678693736 [following]
# --2023-03-13 07:33:22--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNDQOYMLX4&Signature=X8Vxx%2FPDxQxqAiBk1ba5a5eHWUQ%3D&x-amz-security-token=FwoGZXIvYXdzEBEaDGWLHGj7QGBpt785WCK%2BAcK9cWzC4LDq1YoeaDEnysirAHuvwfS2GrjKLWtEIzVz3zbHUAhPm4kx5bEN374CW3cW48SWLhBAf4iC6nH8PpVWNVzZpIg8AuQSpFBD8LeVSFnHkin5Yk%2FS3IPN45D77ggvOJczAVLHFiEf7ek9CnxTD1MF%2BZbuAkAJiERBN1DNcD7wWaKKw%2FpTZ%2BJMeacu8kSM%2FsgOB4TFp22jGSgSnojOLj8Ms7ciW4LRfyGJv2zFrzbk01vEFPffAtDoO5Yo4Jy7oAYyLaCgZSXgWk04uGUxhH%2BI2XCRpIaVbDP5UBhgQZaRmEa2XNl2z9lgRISFUrhnKg%3D%3D&Expires=1678693736
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 3.5.3.140, 54.231.225.217, 52.216.221.193, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|3.5.3.140|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  12.0MB/s    in 5.0s
#
# 2023-03-13 07:33:28 (9.56 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.

# %% [markdown]
# ---
# # 형태소 분석기 비교
# ---

# %%
import numpy as np

from konlpy.tag import Okt, Kkma, Komoran, Hannanum
from konlpy.utils import pprint

import time

# %%
text = '우리부에서는 대전광역시 도청 일대에 국립국어원문화전당을 23년 준공을 목표로 건립중에 있으며, 현재 문화전당 주변 도시계획도로 공사를 진행하고 있습니다. 이와 관련해서 우리 부에서는 도시계획도로 공사가 완료되기 전에 문화전당용 관로포설 우선 시공을 요청한 바, 귀 본부로 부터 시설 공사비 납부 안내서를 받았습니다.'

# %%
okt = Okt()
kkma = Kkma()
komoran = Komoran()
hanna = Hannanum()
mecab = Mecab()

# %%
tokenized_doc = okt.pos(text)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'Noun'])
pprint(tokenized_nouns)
# Out:
# ('우리 부 대전광역시 도청 일대 국립국어원 화전 준공 목표 건립 현재 문화 전당 주변 도시 계획 도로 공사 진행 이 관련 우리 부 도시 '
#  '계획 도로 공사 완료 전 문화 전당 용 관로 포설 우선 시공 요청 바 귀 본부 부터 시설 사비 납부 안내서')

# %%
tokenized_doc = kkma.pos(text)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1].find('NN') == 0])
pprint(tokenized_nouns)
# Out:
# ('부 대전광역시 도청 일대 국립 국 어원 문화 전당 년 준공 목표 건립 중 현재 문화 전당 주변 도시 계획 도로 공사 관련 부 도시 계획 '
#  '도로 공사 완료 전 문화 전당 관로 포설 우선 시공 요청 바 귀 본부 시설 공사비 납부 안내서')

# %%
tokenized_doc = komoran.pos(text)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1].find('NN') == 0])
pprint(tokenized_nouns)
# Out:
# ('부 대전광역시 도청 일대 국립국어원 문화 전당 년 준공 목표 건립 중 문화 전당 주변 도시 계획 도로 공사 진행 관련 부 도시 계획 도로 '
#  '공사 완료 전 문화 전당 관로 포 설 시공 요청 바 귀 본부 시설 공사비 납부 안내서')

# %%
tokenized_doc = hanna.pos(text)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1] == 'N'])
pprint(tokenized_nouns)
# Out:
# ('우리부 대전광역시 도청 일대 국립국어원문화전당 23년 준공 목표 건립중 문화전당 주변 도시계획도 공사 진행 이 관련해서 우리 부 '
#  '도시계획도 공사 완료 전 문화전당용 관로포설 시공 요청 바 귀 본부 부터 시설 공사비 납부 안내서')

# %%
tokenized_doc = mecab.pos(text)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1].find('NN') == 0])
pprint(tokenized_nouns)
# Out:
# ('부 대전광역시 도청 일대 국립 국어 원문 전당 년 준공 목표 건립 중 문화 전당 주변 도시 계획도 공사 진행 관련 부 도시 계획도 공사 '
#  '완료 전 문화전 당용 관로 포설 시공 요청 바 귀 본부 터 시설 공사비 납부 안내서')

# %% [markdown]
# ---
# # N_gram
# ---

# %% [markdown]
# - countvectorizer는 문서 내에서 각 단어의 출현 빈도를 카운트하여 단어를 벡터화 하는 기능
#
# - KeyBERT는 단어의 출현 빈도를 기반으로 단어를 추출하는 countvectorizer를 사용하여
# 문서 내에서 단어의 상대적인 빈도를 고려해 단어의 중요도를 결정한다.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer

# %% [markdown]
# - ngram_range는 생성할 n-gram의 범위를 설정하는 매개변수
#
# - (n_min, n_max)의 형태이며
#
# - (1,1)로 설정하면 단어의 출현 빈도만을 기반으로 텍스트를 벡터화 == 유니그램
#
# - (1,2)로 설정하면 모든 유니그램과 바이그램을 추출하요 텍스트를 벡터화
#   - 바이그램 = 두 개의 연속된 단어를 하나의 토큰으로 표현한 것 (apple juice)

# %%
doc = '''이 글에서는 국어 운율의 변천과 발달을 다루었다. 국어는 음조의 변별성 여부에 따라서 성조방언, 
         비성조방언으로 나눌 수 있는데 지금까지의 연구에서는 이 둘을 관련시키지 않고 따로 연구하여 왔다. 
         이렇게 함으로써 있을 수 있는 공통점을 파악할 수 없게 되었다. 
         이 글에서는 기존의 연구를 통합적으로 파악하여 현대국어의 각 방언의 운율체계가 그 이전에 있던 운율체계에서 발달되어 온 것임을 보이고자 한다. 
         제1장에서는 중세국어의 언어는 중부방언을 반영하고 있는 것이 아니라 함경방언을 나타낸 것이라는 주장이 있어서 
         이를 간략히 소개하고 이러한 문제를 검토하기 위하여 역사언어학적 관점에서 중세국어와 현대방언을 종합하여 파악해야 할 필요가 있음을 주장하였다. 
         2장에서는 비성조방언과 성조방언에서 나타나는 운율의 공통점과 차이점을 보이고자 하였는데, 기존 연구를 인용하여 비성조방언도 성조방언과 마찬가지로 
         LH, HH, H̅L 등의 음조를 가지고 있음을 보였으며, 다만 이들 음조형을 지니는 어사들은 어두 자음 또는 모음의 장단에 의해 정해지는 비변별적인 것으로 파악하였다. 
         그리고 HH형은 함경방언에서만 나타나지 않는다는 사실을 통해서 함경방언이 독자적인 발달을 한 방언임을 보였다. 
         제3장에서는 중세국어의 성조가 현대 여러 방언에 어떻게 반영되어 있는가를 논의하였는데 지금까지 경상방언 평성형 어절에서 높낮이가 서로 바뀌었다는 주장에 대해서, 
         후속하는 음절의 H가 한 음절씩 앞으로 옮겨졌다는 주장을 하였으며 이것을 예기발음 현상으로 보았다. 그리고 HH로 시작하는 거성형 어절은 변함없이 그대로 실현됨을 보였다. 
         결론적으로 중세국어의 성조는 당시의 중부방언을 반영하는 것이며, 
         그것이 역사언어학적으로 인근 언어에서도 볼 수 있는 보편적인 언어 변화를 겪으면서 현대 여러 방언의 성조체계나 음조체계로 발달하였음을 주장하였다.'''

# %%
# 명사만 추출
tokenized_doc = mecab.pos(doc)
tokenized_nouns = ' '.join([word[0] for word in tokenized_doc if word[1].find('NN') == 0])
pprint(tokenized_nouns)
# Out:
# ('글 국어 운율 변천 발달 국어 음조 변별성 여부 성조 방언 성조 방언 수 지금 연구 관련 연구 수 공통점 파악 수 글 기존 연구 통합 '
#  '파악 현대 국어 방언 운율 체계 이전 운율 체계 발달 것 장 중세 국어 언어 중부 방언 반영 것 함경 방언 것 주장 소개 문제 검토 역사 '
#  '언어학 관점 중세 국어 현대 방언 종합 파악 필요 주장 장 성조 방언 성조 방언 운율 공통점 차이점 기존 연구 인용 성조 방언 성조 방언 '
#  '마찬가지 등 음조 음조 어사 자음 모음 장단 비변 것 파악 형 함경 방언 사실 함경 방언 독자 발달 방언 장 중세 국어 성조 현대 방언 '
#  '반영 논의 지금 경상 방언 평성 어절 높낮이 주장 후속 음절 음절 앞 주장 예기 발음 현상 시작 거성 어절 실현 결론 중세 국어 성조 '
#  '당시 중부 방언 반영 것 역사 언어학 인근 언어 수 보편 언어 변화 현대 방언 성조 체계 음조 체계 발달 주장')

# %%
n_gram_range = (1, 2)

count = CountVectorizer(ngram_range=n_gram_range).fit([tokenized_nouns])
candidates = count.get_feature_names_out()

print('trigram 개수 :',len(candidates))
print('trigram 다섯개만 출력 :',candidates[:5])
# Out:
# trigram 개수 : 169
# trigram 다섯개만 출력 : ['거성' '거성 어절' '검토' '검토 역사' '결론']

# %%
model = SentenceTransformer('sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens')
# Out:
# Downloading (…)ab895/.gitattributes:   0%|          | 0.00/574 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)f9e99ab895/README.md:   0%|          | 0.00/4.06k [00:00<?, ?B/s]
# Downloading (…)e99ab895/config.json:   0%|          | 0.00/731 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# Downloading (…)99ab895/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
# 문장의 임베딩 값
doc_embedding = model.encode([doc])
# candidate의 임베딩 값
candidate_embeddings = model.encode(candidates)

# %%
print(doc_embedding.shape)
print(candidate_embeddings.shape)
# Out:
# (1, 768)
# (169, 768)

# %%
top_n = 5
# 문장 유사도 비교 
distances = cosine_similarity(doc_embedding, candidate_embeddings)
# 오름차순 정렬
keywords = [candidates[index] for index in distances.argsort()[0][-top_n:]]

# %%
print(distances.shape)
# Out:
# (1, 169)

# %%
keywords
# Out:
# ['언어학 관점', '언어학', '발달 국어', '언어 변화', '국어 운율']

# %% [markdown]
# ---
# # Max Sum Similarity
# ---

# %%
import itertools

'''기존 코드로 keywords를 뽑으면 유사한 키워드들이 나오게 된다. 
   이를 해결하기 위해 사용되는 알고리즘으로
   상위(top_n)개의 키워드 중에 서로 가장 유사성이 낮은 nr_candidates를 선택하는 방식이다.
   
   즉, 후보 간의 유사성을 최소화하면서 문서와 후보 유사성을 극대화하고자 한다.'''

def max_sum_sim(doc_embedding, candidate_embeddings, words, top_n, nr_candidates):
    # 문서와 각 키워드들 간의 유사도
    distances = cosine_similarity(doc_embedding, candidate_embeddings)

    # 각 키워드들 간의 유사도
    distances_candidates = cosine_similarity(candidate_embeddings, 
                                            candidate_embeddings)

    # 코사인 유사도에 기반하여 키워드들 중 상위 top_n개의 단어를 선택
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    
    # word_idx에 해당하는 행과열만 추출하여 새로운 배열 생성
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # 각 키워드들 중에서 가장 덜 유사한 키워드들간의 조합을 계산
    min_sim = np.inf
    candidate = None

    # words_idx에서 top_n개의 요소로 이루어진 조합을 생성
    for combination in itertools.combinations(range(len(words_idx)), top_n):
        # 리스트에 포함된 키워드 간의 유사도 합을 계산
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

# %%
max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=5, nr_candidates=10)
# Out:
# ['현대 방언', '언어 중부', '현대 국어', '언어학', '언어 변화']

# %%
max_sum_sim(doc_embedding, candidate_embeddings, candidates, top_n=5, nr_candidates=30)
# Out:
# ['발달 주장', '중부 방언', '보편 언어', '역사 언어학', '언어 변화']

# %% [markdown]
# ---
# # Maximal Marginal Relevance
# ---

# %%
def mmr(doc_embedding, candidate_embeddings, words, top_n, diversity):
    '''다양성은 diversity로 조절을 하며 0 ~ 1 사이의 값으로 설정
       1일 경우, 선택된 키워드들이 서로 최대한 유사하지 않도록 선택
       0일 경우, 선택된 키워드들이 최대한 유사하도록 선택
    '''

    # 문서와 각 키워드들 간의 유사도가 적혀있는 리스트
    word_doc_similarity = cosine_similarity(candidate_embeddings, doc_embedding)

    # 각 키워드들 간의 유사도
    word_similarity = cosine_similarity(candidate_embeddings)

    # 문서와 가장 높은 유사도를 가진 키워드의 인덱스를 추출.
    # 만약, 2번 문서가 가장 유사도가 높았다면 keywords_idx = [2]
    keywords_idx = [np.argmax(word_doc_similarity)]

    # 가장 높은 유사도를 가진 키워드의 인덱스를 제외한 문서의 인덱스들
    # 만약, 2번 문서가 가장 유사도가 높았다면 ==> candidates_idx = [0, 1, 3, 4, 5, 6, 7, 8, 9, 10 ... 중략 ...]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    # 최고의 키워드는 이미 추출했으므로 top_n-1번만큼 아래를 반복.
    for _ in range(top_n - 1):
        # 문서와 각 키워드들 간의 유사도 중에서, 선택된 후보 키워드와의 유사도를 계산
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        
        # 선택된 키워드와 각각의 키워드와의 유사도 중 가장 큰 값을 계산
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # 후보 키워드와 target_similarities간의 가중합을 계산
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        
        # 가장 mmr이 큰 후보 키워드의 인덱스를 선택
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # 선택된 키워드에서 mmr이 가장 큰 후보 키워드를 추가
        keywords_idx.append(mmr_idx)
        # 키워드 제거
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.1)
# Out:
# ['국어 운율', '언어 변화', '발달 국어', '언어학', '현대 국어']

# %%
mmr(doc_embedding, candidate_embeddings, candidates, top_n=5, diversity=0.7)
# Out:
# ['국어 운율', '기존 연구', '공통점 차이점', '보편', '중세']
