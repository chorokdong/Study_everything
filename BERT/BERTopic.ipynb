# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.9/dist-packages (4.27.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kss
#   Downloading kss-4.5.1.tar.gz (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.7/77.7 KB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting emoji==1.2.0
#   Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.3/131.3 KB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from kss) (2022.10.31)
# Collecting pecab
#   Downloading pecab-1.0.8.tar.gz (26.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.4/26.4 MB 46.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from kss) (3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from pecab->kss) (1.22.4)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.9/dist-packages (from pecab->kss) (9.0.0)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from pecab->kss) (3.6.4)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pytest->pecab->kss) (9.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.9/dist-packages (from pytest->pecab->kss) (1.16.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.9/dist-packages (from pytest->pecab->kss) (0.7.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pytest->pecab->kss) (67.6.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from pytest->pecab->kss) (1.11.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.9/dist-packages (from pytest->pecab->kss) (22.2.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.9/dist-packages (from pytest->pecab->kss) (1.4.1)
# Building wheels for collected packages: kss, pecab
#   Building wheel for kss (setup.py) ... done
#   Created wheel for kss: filename=kss-4.5.1-py3-none-any.whl size=53220 sha256=103a4c1c8f8e4e4159f5ff19e15b991a2af4603c576f54e75bc1082c74388898
#   Stored in directory: /root/.cache/pip/wheels/2f/23/d1/e9c8f5f2e8a61bb4cb8e4fdd0d0c951dab78882e3807c7f7ca
#   Building wheel for pecab (setup.py) ... done
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646666 sha256=48b923da971b829f9a420951d6e864ff46e42d8bcaeec170c211dfb03a1424ca
#   Stored in directory: /root/.cache/pip/wheels/5c/91/bf/14eed6eafd0a83f76eab5cf8eb50ddc0b037f059eec2bd2e4a
# Successfully built kss pecab
# Installing collected packages: emoji, pecab, kss
# Successfully installed emoji-1.2.0 kss-4.5.1 pecab-1.0.8

# %%
import numpy as np
import pandas as pd 
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ----
# # Data
# ---

# %%
path = '/content/drive/MyDrive/2.Study/BERT/KCC150_K01.txt'

data = []
with open(path, 'r', encoding='cp949') as f:
  for _ in range(4000):
    data.append(f.readline().strip())

data
# Out:
# ['통합보건교육은 이 대학만의 특화된 프로그램이다.',
#  '이에 따라 전달된 후원금은 저소득층과 사회복지시설에 2억원 상당을, 중구 푸드뱅크 설립 지원에 6000만원, 저소득 긴급지원과 시설 등의 지원에 5000만원이 전해진다.',
#  '오리콤은 이에 모든 조직과 프로세스를 바꾸기로 했다.',
#  '방사청은 이번 원가관리 안내서를 희망하는 기업에 무료로 배포할 예정이다.',
#  '그러나 이 건물은 겉에서 보는 것과는 달리 지어진 지가 꽤 오래되었는지 방이 약간 낡았다는 느낌을 주었다.',
#  '그런데 황희찬이 다시 1부로 올라갈 수도 있다.',
#  '응답자 중 가장 많은 의견이었다.',
#  'P씨는 23일 오전 8시30분쯤 벤츠 승용차를 몰고 서울 마장동 내부순환로를 달리다 커브길에서 좌우 방호벽을 차례로 들이받았다.',
#  '니트는 당초 수능 영어를 2015년부터 대체할 계획이었지만 2019년까지 미뤄지는 등 난항을 겪어왔다.',
#  '세계 금융시장이 극심한 공포에서 잠시 벗어났다.',
#  '반면 글로벌 금융위기의 주범이었던 선진국의 살림살이는 크게 악화됐다.',
#  '경기도 체육회가 주최하고 경기도 및 가평군 태권도협회가 주관하는 이번 대회에는 도내 31개 시군 생활체육 동호인 2600여 명이 참가해 겨루기, 품세, 격파 종목에서 지역 및 개인의 명예를 빛내기 위해 한판 승부를 펼치게 된다.',
#  '사실 국내 업체들은 확장성에서 좋은 평가를 받고 있다.',
#  '군은 송기섭 군수의 지시로 작년 말 2017년 주요업무계획을 수립하면서, 기존 연도만 바꿔 소위 표지갈이 식으로 연례반복적으로 작성되던 업무계획에서 탈피, 수차례의 성과보고회 개최를 통한 성과와 과오점에 대한 철저한 분석을 통해 주요업무계획이 수립된바 있다.',
#  '웹접근성 인증은 한국정보화진흥원이 장애인이나 고령자도 편리하게 이용할 수 있도록 제작되고 관리하는 홈페이지에 부여합니다.',
#  '연예인으로는 방송인 김지민씨가 대표령 표창을, 방송인 최현정씨과 프로야구 선수 권혁이 국무총리표창을, 배우 김서형, 배우 김정은씨가 각각 금융위원장 표창을 받았다.',
#  '사실 실물경제의 붕괴를 걱정하는 정부의 속내는 구조조정이 약간 미흡하게 끝나더라도 경기부양쪽으로 기울고 있는 것 같다.',
#  '소방당국은 진화가 완료되는 즉시 목격자 등을 상대로 정확한 화재 원인을 조사 할 방침이다.',
#  '18거래일 동안 매섭게 매도물량을 내놓았던 외국인은 현재 91억을 순매도하고 있다.',
#  '정부는 조속히 해당 부품을 교체하는 한편 사건 책임자 문책 및 재발방지에 만전을 기한다는 방침이다.',
#  '사회 모든 부문의 활동과 자원의 생산 및 분배는 그들에 의해서만 관리되고 통제된다.',
#  '스트레스 해소음식 감은 피부 미용과 감기 예방에 좋은 비타민 C와 A,B까지 모두 갖고 있어, 비타민의 끝판왕이라고 불린다.',
#  '미국 엄마는 새로운 육아법과 육아용품에 극도로 민감한 반면, 프랑스 엄마는 궁금한 게 생기면 자기 엄마한테 물어본다.',
#  '통산 1366경기에 출전해 평균 19.3점, 10.9리바운드, 2.2블록을 기록했다.',
#  'LH 경기본부가 전세대란 최적의 대안으로 꼽고있는 수원 세류지구를 눈여겨 볼 만 하다.',
#  '하지만 최근 정부의 공공기관 정상화 정책으로 각종 복지 혜택이 줄어들고, 대우조선해양 사태 등에 따른 책임론이 부각되며 국민적인 질타까지 받고 있다.',
#  '천혜의 경치를 자랑하는 다도해를 무대로 펼쳐지는 이번 대회는 전남도와 목포시가 주최하고 문화체육관광부가 후원한다.',
#  '대부분의 의료인이나 일반인은 주로 소독을 멸균과 별 차이 없이 사용하고 소독했다고 하면 멸균한 것과 마찬가지로 생각하기 쉽다.',
#  '경찰은 혐의 소명을 보완해 체포영장을 재신청하기로 했습니다.',
#  '학교측은 A학생이 출산후 신생아를 유기한 사실을 확인하고 우선 학생을 진정시키기 위해 병원에 입원시켰다.',
#  '경북 김천에서 강간을 저지르고 흉기를 가진채 도주하던 20대 남성이 부산에서 경찰에 붙잡혔다.',
#  '한편, 활동 종료 후 수료증이 제공되며, 우수활동자 선발 및 포상과 모두투어 입사 지원 시 가산점이 주어진다.',
#  '실제로 샌프란시스코 다운타운 내에 등록된 차가 인구 대비 줄어들고 있다.',
#  '마리오 드라기 유럽중앙은행 총재가 또 초대형 경기 부양에 나선다.',
#  '기능성 화장품은 기본이며, 남성 타깃으로 비비 크림, CC 크림 등 메이크업까지 남성을 위한 신제품들이 쏟아져 나온다.',
#  '노동청은 최저임금을 보다 낮은 임금을 주거나, 주휴수당을 주지 않아 발생한 미지급 임금 1800만원을 근로자들에게 지급하도록 했다.',
#  '올해로 프로 18년차인 그는 시즌 개막전부터 엔트리에 이름을 올렸고, 한 번도 2군에 내려가지 않고 붙박이 1군 멤버로 공수에서 중추적인 역할을 해내고 있다.',
#  '프레드는 전방으로 온 패스를 놓치지 않고, 수비수와의 경합을 이겨내고 슛까지 이어가며 브라질의 쐐기골을 넣었다.',
#  '그동안 오프라인 배달로만 치킨을 판매하는 방식에서 벗어나 다양한 판매망 확보로 가맹점주가 직접 홍보활동을 하지 않고 본사에서 대형 쇼핑몰과 제휴를 통해 홍보함으로써 가맹점의 실질적인 매출 증대에 도움을 주고 있다.',
#  '부산 연제경찰서는 20일 보험판촉물 납품업체 대표에게 돈을 빌린 뒤 갚지않은 보험대리점 간부 A씨를 사기 혐의로 불구속 입건했다고 밝혔다.',
#  '해외에 상장된 ETF를 매매해 국내상장 해외 ETF에 비해 절세혜택도 누릴 수 있다.',
#  '열 살 남짓의 소녀들은 뜻밖의 외지인이 있어 부끄러웠는지 농기구를 내던지듯 하고 내뺐다.',
#  '남자부에서는 강성균,권오희팀이 우승을 다투게 된다.',
#  '남대문시장 상가들의 공식적인 영업시간은 오후 6시까지다.',
#  '연신 물세례를 퍼부는 친구들의 짓궂은 장난도, 서툰 수영솜씨도 싫지 않은 모습입니다.',
#  '조기 등판한 윤석민이 무너지면서 슬픔은 두 배가 됐다.',
#  '안 원장의 대선출마 시기도 여러 가능성이 있다.',
#  '그들의 주변과 그들의 몸안을 가득 채우고, 감각 세포를 무자비하게 잠식해 들어오던 그 소리는 그들의 몸의 일부가 된 상태로 끝나버려 그대로 응고되어 가는 것이다.',
#  '이번 골프토토 스페셜 26회차는 27일 오후 6시 50분에 발매가 마감되며, 1라운드가 모두 종료된 후에 결과가 공식 발표된다.',
#  '김씨는 변호사의 도움을 받아 이의신청을 냈다.',
#  '어떤 때는 무척이나 야속하다.',
#  '캡에 이 차량을 공급하게 된다.',
#  '밖에서 비효율적으로 시간을 보낸 일이 많았다.',
#  '해당 주택은 길상사 인근 각국 대사관 밀집지역 등 고급 주택가에 위치한 빌라다.',
#  '네오위즈게임즈의 공개 서비스에 앞서 23일, 오후 4시부터 11일간 사전 공개 서비스를 실시한다고 밝혔다.',
#  '또한 넓은 대리석과 주차장 등이 조성됐다.',
#  '나나는 사고직후 바로 병원으로 이동하여 정밀 검진을 받았고, 다행히 큰 부상은 없는 것으로 밝혀졌다.',
#  '기술주 중심의 나스닥은 33.84포인트 오른 6912.36을 기록했다.',
#  '아이보리색 두루마기에 비취색 치마를 차려 입고 등장한 박 대통령은 먼저 박물관 3층을 찾았다.',
#  '여야 협상이 지지부진한 상황에서 원내지도부가 직접 나서야 한다는 지적도 나오고 있지만 이들 또한 사실상 협상을 관망할 뿐, 뚜렷한 대책을 내놓지는 못하고 있다.',
#  '그는 스마트폰, 스마트TV 등 가전제품을 원가에 판매한다는 조건을 내걸고 러스왕의 유료 회원을 모집했다.',
#  '김기림은 길에 대해서 다음과 같이 아름답게 노래한 적이 있었다.',
#  '대표 관광지인 수덕사는 6만 1758명, 예당관광지는 5만 9772명, 봉수산자연휴양림 4만 9041명으로 집계됐다.',
#  '올 시즌 역시 흔들리는 6월이다.',
#  '13일 업계에 따르면 금호타이어 관계자들은 전날 산업은행을 방문, 자구계획안을 제출했다.',
#  '섬의 비밀과 남편이 저질렀을지도 모르는 어떤 범죄 사실이 육지로 알려지면 안되겠기 때문이었다.',
#  '1승을 만회하면 자연히 롯데에서 압박감이 커질 것이다.',
#  '양산에서 화학약품제조업을 하고 있는 양희우 협회장은 홈페이지 관리에는 이제 완전히 전문가가 되었는데 부산오픈홈페이지 뿐만 아니라 부산시협회 홈페이지도 맡아서 관리하고 있다.',
#  '정부입장에서도 정책의 정당성을 획득하고 정책집행의 순응성을 높일 수 있다.',
#  '뇌물공여 혐의 역시 포스코켐텍 협력사를 인수하게 한 것이 청탁 대가로 보기 어렵다는 이유에서다.',
#  '인천 주안역 근처 역세권에 위치하며 인하대학교, 청운대학교, 재능대학교 등과 주안국가산단 등이 자리잡고 있다.',
#  '미국 유기농 전문 수퍼마켓 체인인 홀푸드마켓은 미국 내에서도 고급스러운 이미지를 자랑한다.',
#  '그는 올해 3월 노동당 조직지도부 부부장에서 제1부부장으로 승진했다.',
#  '산림복지 전문업은 최근 늘어나는 숲 해설 수요를 맞추기 위해 자연휴양림과 수목원 등에 숲 해설가를 추가 배치해 산림휴양서비스 만족도를 높여나갈 계획이다.',
#  '21일 경기에선 마무리 투수 김사율까지 부진하며 고민을 더했다.',
#  '둘의 재회를 바라는 마음에서 일을 꾸미지만, 뜻대로 되지 않는다.',
#  'NTC 측은 특히 당장 시급한 주택, 병원, 학교 등을 건설하는 데 적극 참여해 줄 것을 요청했다.',
#  '결혼 전의 모습과 무관하게 강하고 현명한 엄마, 내조 잘하는 든든한 부인의 역할을 성실히 수행하느라 여자로서의 모습을 잃어간다 생각할 때다.',
#  '인터넷매체 뉴스타파는 얼마 전 한국 기업인들 가운데 조세피난처에 페이퍼컴퍼니를 설립한 5명의 명단을 공개한 데 이어 이날 2차 명단을 공개했다.',
#  '가진 팀은 최대 2개 팀까지 출전할 수 있다.',
#  '앞의 두 경우는 성격이나 능력상 믿을 수 없거나 신뢰할 수만은 없는 서술자들이고, 뒤의 경우는 등장인물들과 너무 거리를 두고 있는 서술자이다.',
#  '선수들은 멋진 세러머니를 준비했다.',
#  '스폰서 수입은 8억6000만 엔에 달했다.',
#  '메콩강을 건너 시장에서 잠시 차를 멈춘 운전사는 연밥을 사들고 왔다.',
#  '새누리당 윤상현 원내수석부대표는 오늘 국회에서 열린 의원총회에서 국정원이 작성한 댓글을 모두 읽어봤지만 검찰이 법 상식에 비해 선거법을 무리하게 적용했다고 주장했습니다.',
#  '공개된 사진 속 티파니는 화장기 없는 얼굴에 또렷한 이목구비로 미모를 과시했다.',
#  '강병구 국세행정개혁 TF 단장이 31일 오전 정부세종2청사 국세청에서 국민과 함께하는 공정한 세정 구현을 위한 국세행정 운영방안을 발표하고 있다.',
#  '무균성인 경우세균성보다 증상이 가볍고 후유증을 남기는 경우도 적다.',
#  '먼저 약속을 어긴 쪽은 한달준 그 놈이었어.',
#  '학생들에게 한 문제라도 더 풀게 하려는 학원강사의 열정이 웃음을 자아낸다.',
#  'YSX기는 일본이 개발해 운행되고있는 YS11기의 후속기종으로 일본이 차세대소형여객기 성장에 착안해 개발키로 한 기종이다.',
#  '절체절명의 위기에 김경문 NC 감독의 선택은 정수민이었다.',
#  '틈만 나면 여기저기에 흔적을 남기는 바람에 집안구석 여기저기에 냄새가 풍겨서 괴롭기도 하다.',
#  '충북본부는 장보기를 통해 구입한 물건을 인근 사회복지시설에 기부했다.',
#  '앞서 이병헌과 이민정은 지난 7일 미국으로 동반 출국했으며 이병헌은 12일 새벽에, 이민정은 13일 새벽에 입국해 하루 차이로 귀국했다.',
#  '시는 또 농지인 이 펜션 주변 일부 부지가 불법으로 전용됐다는 사실을 확인, 소유자에게 원상복구 명령을 내렸다.',
#  '꽃 물결에 발걸음이 한층 가벼워집니다.',
#  '이에 따라 편리하게 갈아끼우는 보조 배터리를 추가 증정한다고 하면 소비자들이 관심을 갖는다는 설명이다.',
#  '그때처럼, 꿈속에서도 꽃이 피어 있었다.',
#  'SNS는 그의 방출에 직접 영향을 미쳤다.',
#  'SK 투수 문광은이 비에 울고, 야수진의 아쉬운 수비에 주저 앉았다.',
#  '모두가 동일한 DNA 구조를 가지고 있는 것이 대표적 증거다.',
#  '조안면 주민들은 기업형 불법영업 음식점으로 알려져 있지만 사실과 다르다고 주장한다.',
#  '현재 사업지연으로 조합설립인가 후 2년 이상 사업시행인가 신청을 못하면 2년 이상 소유에 한해 예외적으로 조합원 지위 양도가 허용됩니다.',
#  '김하성과 야마카와 호타카의 4번타자 대결이 다시 펼쳐진다.',
#  '라스베이거스 호텔들의 경비 요원 5000여 명이 경찰과 협조해 수상한 움직임이 포착될 경우 정보를 공유하기로 했다.',
#  '18일 오후 광화문에서 집회 중인 참가자들이 세종문화회관 인근에 앉아 휴식을 취하고 있다.',
#  '시는 듯한 황홀한 시세계에 전율하게 된다.',
#  '르네상스 시대를 풍미했던 프랑스 궁전에서 한국 현대시를 읊는 소리가 들렸다.',
#  '홍익대도 2011년 323억원, 2012년 416억원으로 93억원이 불었다.',
#  '민주당은 이날 오전 9시 김한길 대표를 비롯한 당 지도부가 진주의료원 앞마당에서 최고위원회의를 개최한다고 밝혔다.',
#  '아파트 매매가가 가장 크게 떨어진 곳은 서울 용산구였다.',
#  '음성군이 미분양용지에 대한 899억 원을 책임 보증하는 조건으로 진행하는 성본산단도 그 동안 일부 의원들의 반대로 많은 진통을 겪은 바 있으나, 결국 지역발전을 바라는 군민 의견이 반영되었다는 평가다.',
#  '선배들이 방패막이 역할을 하면서 현직에 있는 후배들의 감독 기능은 무뎌질 수밖에 없다는 얘기다.',
#  '따라서 대표팀 선발 일정도 앞당겨질 수밖에 없다.',
#  '내가 관리야구를 하니 관리야구가 많아졌다.',
#  '안전 수송을 위해 특수 제작된 상자에 실려 고향에 가게 될 흑두루미는 모스크바 동물원에 인계된다.',
#  '경기 김포시는 5월까지의 공장건축 총허용량과 집행실적을 고시했다고 13일 밝혔다.',
#  '이번에 MS가 선보인 태블릿PC는 윈도RT를 운영체제로 활용한 서피스RT와 윈도8을 탑재한 서피스 프로다.',
#  '현대모비스 인사팀 직원들이 학생들에게 자기소개서 작성법과 면접 요령 등 취업과 관련한 구체적인 멘토링을 해줄 계획이다.',
#  '부상과 부진이 겹치며 정규리그 34경기 중 16경기 출전에 그쳤다.',
#  '후진적인 군의 체질을 바꿀 수 있는 근본적인 대책 마련이 뒤따를 전망이다.',
#  '연령별로는 20대가 404명가 뒤를 이었다.',
#  '개소하는 청각평형검사센터는 청각과 어지럼증 등 귀와 관련한 다양한 질환에 대해 검사실을 옮겨다니며 검사하는 불편함을 줄였다.',
#  '새 외국인 선수 존 쿠엘 존스의 활약이 무서웠다.',
#  '그는 몹시 다잡한 경향을 지니고 있었고 많은 경박한 글들을 여기저기에 발표하고 있었거든요.',
#  '적발된 업체들의 경우 관계기관에 행정 통보할 예정이다.',
#  '그 외 중국 방문 기간 박 대통령은 중국어 연설 등 여러 가지 형식으로 중국 국민들의 관심과 주목을 받았다.',
#  '버티고 버티다가 막판 절충안으로 합의를 했어야 한다.',
#  '시골 군옥이라면 토옥이니 한 열 명 남짓이면 가득 찰 것이며 서울 포청의 전옥서에는 수백 명이 끓는답디다.',
#  '하지만, 그 과정에서 과거의 문제가 밝혀져 1927년 4월 정권이 교체되었다.',
#  '현강정보고등학교 엄단지양은 취업담당관 선생님과 함께 고심한 끝에 이날 동아제약 부스에 사전면접을 신청했다.',
#  '도심의 제한속도를 낮추는 일의 필요성과 그 효과를 공유하는 세미나가 전국 곳곳에서 개최된다.',
#  '게임의 첫인상을 전달하는데 그쳤던 시연버전과 달리, 이번에는 전체적인 게임 전반을 체험할 수 있었다.',
#  '마이클 에시앙, 설리 문타리 등 스타 플레이어들이 대거 포진했다.',
#  '며칠 전, 그 300호가 새삼스러워졌다.',
#  '직접 정상들과 전화 외교전에 나서기도 했다.',
#  '제이버드 런은 20만 원대 출시가로 프리미엄에 가까운 가격대지만 그에 어울리는 품질을 충실하게 갖췄다.',
#  '경찰은 흑색선전, 선거폭력, 불법단체 동원 등을 반드시 척결해야 하는 3대 선거범죄로 규정했다.',
#  '끝내, 나는 자꾸만 파고드는 여자의 손을 꼭 쥠으로써 그녀의 행동을 제지하고 말았다.',
#  '10월 하순 이후 이회창 한나라당 후보에게 뒤지기 시작했고, 최근 들어서는 지지도 연쇄 추락으로 노무현 후보에게도 역전당하는 처지에 몰리게 됐다.',
#  '최근에는 이러한 활동을 인정받아 매니페스토365캠페인 한국본부에서 주최하는 시상식에서 소통대상 부문 우수상을 받았다.',
#  '케냐, 우간다, 이집트의 오지가 활동무대다.',
#  '최종거래일은 2013년 9월 13일로 잔존만기는 61일 남았습니다.',
#  '사진 속 여성은 과도한 화장으로 큰 눈과 큰 입을 연출했다.',
#  '이날 유벤투스의 골문을 지킨 부폰은 유독 운이 따르지 않았다.',
#  '그게 제대로 먹히기만 하면, 지금 느끼는 이런 비참한 기분을 충분히 갚아주고도 남을 거야.',
#  '이스라엘 민족은 하느님이 선민 사상을 지니고 많은 나라들을 침공하고 약탈과 살인을 일삼았을 뿐만 아니라, 다윗 왕가에서 그들을 다스리고 평화의 왕 메시아가 오시리라는 예언의 실현을 학수고대하면서 포로 생활과 민족 분산과 집단 학살을 감내해 왔으며, 오늘도 여전히 중동의 화약고 속에서 전쟁의 가능성을 항상 지니고 있습니다.',
#  '한편 황각규 롯데지주 공동대표, 소진세 사회공헌위원장, 이원준 유통BU장, 이재혁 식품BU장, 허수영 화학BU장 등 롯데 수뇌부는 25일 신동빈 회장의 장인상 조문과 장례식 참석을 위해 일본으로 출국한다.',
#  '더불어민주당 19대 대통령 후보 선출을 위한 호남권 순회경선이 27일 오후 2시 광주여대 유니버시아드 체육관에서 열린다.',
#  '왜 그런 잔인한, 잔인하고 끔찍한 자해 행위를 사람들 앞에서 서슴없이 하는 거죠?',
#  '정치풍자와 관련되어서 어디까지 표현의 자유를 허용할 것인가의 문제는 나라별로 아직까지 논쟁이 되고 있다고 봅니다.',
#  '살이 빠지면서 몸이 확실히 가벼워졌다.',
#  '어울리는 리스를 함께 걸어줘도 좋다.',
#  '양윤임 여사의 처녀 시절 때 조철구 형제가 함께 사랑했다고 하더군요.',
#  '하지만 이번 선언에는 한국의 글로벌 리더십 참여를 미국이 환영하고, 동북아 평화협력시대 구축방안을 준비하자는 내용이 구체적으로 추가됐다.',
#  '또한 정년퇴직을 하면 폐품신세가 되는데 만일 재취업을 하면 일종의 제품활용이랄까?',
#  '중국증권감독관리위원회는 7일 밤 주식시장의 변동성을 증폭시킨 서킷 브레이커 제도를 잠정 중단한다고 밝혔다.',
#  '감지 센서로는 레이더나 카메라가 사용되며 두 센서가 동시에 적용된 일부 전방충돌방지보조의 경우 보행자까지 감지함으로써 인명 사고 예방에도 상당한 효과를 나타낸다.',
#  '그때까지 자신이 벌여놓은 일들이 갑자기 쇳소리를 내며 어긋나고, 뻥뻥 구멍이 뚫려 그것을 정신없이 수습해야만 하는 힘겹고 소모적인 방어전이었다.',
#  'Q1그런 줄도 모르고, 아뿔싸, 엉뚱한 곳에서 찾았으니 허탕이지.',
#  '수비적인 측면에서도 김신욱의 존재감은 큰 힘이 됐다.',
#  '거절해야 할 상황에 거절을 잘 할줄 아는 사람이야말로 화술의 명수이다.',
#  '속옷 브랜드 휠라 인티모는 전속모델 한혜진의 팬사인회를 성황리에 마쳤다고 12일 밝혔다.',
#  '태블릿 PC들이 레티나급의 패널을 채용할 것으로 보인다.',
#  '요즘 들어 전문대학이 변해가고 있다.',
#  '종전 최저가 낙찰제는 300억원 이상 공사에 대해 최저가 입찰자 순으로 저가심의를 통과한 기업을 낙찰자로 선정하던 방식이다.',
#  '사고원인은 정밀조사를 해야 정확히 밝혀지겠지만 많은 사망자가 났다는점이 이같은 문제점을 단적으로 말해준다.',
#  '그는 이러한 행위가 결코 쿠데타가 아니라고 강조했다.',
#  '김부겸 행정안전부 장관이 18일 오전 백령도 해병대 흑룡부대를 방문, 군장병들과 오찬을 함께하며 격려하고 있다.',
#  '이를 마케팅에 응용한 것이 바로 스토리텔링 마케팅이며, 이미 우리 선조들이 활용했던 방법이기도 하다.',
#  '극장 운영 효율의 지표라 할 수 있는 스크린당 매출 면에서도 중국 톱 10 극장 중에서 1위다.',
#  '외출하실 때는 모자나 선글라스 꼭 챙기시는 게 좋겠습니다.',
#  '지난 4월 중간평가에서는 50개교만 선정됐지만 이후 재선정평가를 거쳐 고려대, 군산대, 대진대, 연세대, 충남대, 한국교원대 등이 다시 합류했다.',
#  '옳아, 산으로 도망친 걸 보니 너도 천주학장이로구나!',
#  '김 위원의 임기는 이날부터 오는 2020년 4월 5일까지 3년이다.',
#  '여름 무더위가 물러간다는 처서인 23일 중부지방에 200mm 이상의 집중호우가 예상되는 등 전국 대부분 지방에 비가 내리겠다.',
#  '침을 꽂아서 그린 원은 어느 것입니까?',
#  '대기업 특혜 논란으로 여야가 첨예하게 대립해 온 외국인투자촉진법의 경우 새누리당이 연내처리에 사활을 걸고 민주당과 담판을 벌였다.',
#  '9월 들어 코스피시장에서 외국인, 기관, 개인 등 주요 투자주체 중 개인만이 유일하게 순매수를 보였으나 수익률은 가장 저조한 것으로 나타났다.',
#  '본시암이 있는 곤제봉을 한 번 더 오르고 싶었다.',
#  '음저협은 하지만 방송사로부터 징수받은 저작권료를 저작권자들에게 분배했어야 했지만 실제로는 분배하지 않았다고 유 의원은 전했다.',
#  '그러나 나와 다른 의견을 가진 사람이 있을 때에 우리는 어떤 태도를 취하여야 하는지 생각하여 봅시다.',
#  '피해 여성은 밤 늦게 호텔 바에서 윤 전 대변인과 함께 술을 마셨는데, 윤 씨가 허락 없이 엉덩이 부분을 움켜쥐었다고 경찰에 진술했습니다.',
#  '이번 업데이트로 노블레스의 주인공 라이제르를 비롯해 프랑켄슈타인, 라스크레아, 세이라, 무자카 등이 등장하며, 캐릭터 코스튬 및 장비와 새로운 스토리도 선보인다.',
#  '여기에 트렁크 공간 역시 상당히 넓다.',
#  '선수들은 보통 한 두 뿌리 정도 먹는데 서장훈은 혼자 다섯 뿌리를 먹었다.',
#  '두 사람은 2011년에 러시아로부터 받은 차관 25억 유로의 만기를 5년으로 연장해 달라고 요청했다.',
#  '올들어 장기화된 소비 침체가 필수소비재 경기로까지 전이되고 있는 모습이다.',
#  '박 전 수석은 재정경제부 1차관과 대통령경제수석비서관을 지냈다.',
#  '전혀 책을 읽거나 공부하는 것을 보지 못했다.',
#  '컴컴한 바닷속에서 엄마를 부르며 죽어 간 아이들의 부모처럼 나도 그 또래의 아이를 키우고 있는 부모였기 때문이었다.',
#  '19살 고졸 신인 이정후가 아버지 못지않은 뛰어난 외모와 실력으로 주목받고 있다.',
#  '킥오프 20분전인 오후 6시40분부터 챔피언십 결승전 당일 우승을 확정하기까지의 이야기를 담은 스케치 영상을 상영한 후, 포항 U18 선수들이 직접 그라운드로 나와 포항 시민들의 성원에 감사 인사를 전한다.',
#  '우리 나름의 합리성과 근대성을 찾아가야 할 때가 되었다.',
#  '연도와 동쪽, 서쪽, 북쪽 벽에 그려진 12명의 인물은 무사, 시위, 내시, 악사 등이다.',
#  '국내 기업들이 직원이 시기와 기간을 자유롭게 선택할 수 있도록 다양한 휴가제도 도입하고 있다고 합니다.',
#  '베컴이 올림픽 대표팀 명단에 이름을 올릴 수 있을지는 남은 소속팀 경기에서 어떤 기량을 보여주는가에 달렸다.',
#  '리빙스턴은 야투 5개를 던져 모두 성공시키는 집중력을 발휘하며 11점을 몰아 넣었다.',
#  '그래도 올해 또 한번 우승을 하고 싶었어요.',
#  '또 증오 연설이나 테러를 선동하는 것과 같은 이슈들에 관해선 인터넷 회사들이 보다 단호한 조치를 취할 수 있도록 더 많은 재량권을 부여하는데도 합의했다.',
#  '장애아와 비장애아를 모두 자녀로 두고 있다면 두 상황을 모두 고려하고 배려하는 지혜가 필요하다.',
#  '조이시티는 주사위의 신의 600만 다운로드 돌파를 기념해 다양한 이벤트를 진행한다.',
#  '한편, 백완기도 이와 유사하게 공익개념의 네 가지 기능을 지적했다.',
#  '그러나 검찰의 약식명령 청구에 법원은 지난 2일 정식재판 회부를 결정했다.',
#  '송하영 총장을 비롯해 교직원과 학생 등 100여명이 참여한 가운데 한밭대 공동실험실습관에서 이뤄진 이날 훈련은 실험 중 화재가 발생한 상황을 가정한 신고, 대피 및 위험물 반출, 화재진압, 강평 등 순서로 진행됐다.',
#  '학생들이 스케치북에 답을 적어 들며 토너먼트식으로 진행된 행사는 창업에 필요한 단계별 상식과 준비 관련 문제를 맞혀 승자를 가렸으며, 박성인 학생이 우수상을 각각 받았다.',
#  '이처럼 가지고 있다고 쉽게 사용하기 어려울 만큼 핵의 파괴력은 엄청나다.',
#  '그러나 그에 걸맞은 기능을 하는지 의문이다.',
#  '이틀, 사흘쯤 기다리는 것은 일도 아니었다.',
#  '그러나 개인이 위협과 공격을 받고 부정되고 무시된다면 영원히 움츠러들거나 기껏해야 그룹에 순응하는 척할지 모른다.',
#  '그래서 무시당했던 적이 있지만, 시간이 지날수록 생활에 밀접한 조례안도 중요하다는 의견이 나왔다.',
#  '오늘 우리는 세계 10위권의 경제대국이요, 국민소득이 3만 달러에 육박하니 무슨 위기냐고 반문할지 모른다.',
#  '한데 지난 78년 서울시가 사육신 묘역을 정화하면서 그곳에 있던 성삼문의 아버지 무덤을 없애버렸다.',
#  '한편 이날 이사회에서는 그룹 국제결제은행 기준 자기자본비율 개선을 위해 상각형 조건부자본증권 발행을 승인했다.',
#  '실제 백현동의 카페거리나 아브뉴프랑은 지나다니는 사람을 손에 꼽을 정도로 한적하다.',
#  '특히 이번 회장 후보들 가운데 허성두, 이영춘, 김택세 대표의 경우 허 대표와 이 대표는 경찰발전위원회에 김 대표는 경찰교통선진발전위원회에 몸담고 있거나 몸담은 전력이 있다.',
#  '정보보호를 위한 제품 이용과 중요 데이터 백업 등 예방활동이 늘었다.',
#  '전주시 내에서도 관리 주체는 분명치 않다.',
#  '지난해 12월25일 도쿄지방재판소에서 진행협의기일이 열렸지만 양측이 팽팽히 맞서며 추후 심리 일정을 잡지 못했고 2월 중 다시 진행협의기일을 열기로 했다.',
#  '따라서 건강하고 아름다운 피부를 유지하기 위해선 계절별 날씨의 특성을 파악하여 미리 예방하는 자세가 필요하다.',
#  '김강민은 올 시즌 안지만을 상대로 7타수 무안타로 약한 모습을 보였다.',
#  '남편 박치열 씨 역시 훈훈한 외모의 이비인후과 의사로 밝혀져 방송 후 많은 누리꾼들의 관심을 받았습니다.',
#  '사람들은 농사를 망친다고 야단이었지만 그는 시뻘건 물말이가 멍석처럼 흘러가는 것이 장엄하게 보였다.',
#  '킨덱스 선진국하이일드, 킨덱스 성장대형F15는 상품성 저하 및 대규모 환매에 따른 신탁원본액 감소로 운용상 어려움을 호소했다.',
#  '나의 모자란 점을 칼을 대서라도 고쳐 바로잡고, 자신감이 생기는 거라면, 해볼만한 일이라고 생각한다.',
#  '퓨져노폴리스 2A 타워 공사는 A,B,C 3개동으로 이뤄져 있으며, A동과 B동을 묶은 건설공사와 C동을 짓는 공사로 분리 발주됐다.',
#  '그러나 나병에 대한 의료기술의 발전과 재가 환우 발굴 사업이 성공적으로 수행되어 1970년대에 와서는 신규 사업이 점차 줄어들었고, 1980년대에 와서는 신규 사업이 없었다.',
#  '가인씨는 똑똑해 보이고 깔끔한 성격을 가진 것 같아요.',
#  '그러나 파우스트 총장의 생각은 곧 바뀌었다.',
#  '14거래일 연속 주식을 내다팔던 외국인들이 매수세로 돌아서면서 주가 상승을 이끌었습니다.',
#  '어느 날 니미츠가 근무하는 함대에 중요한 행사가 열렸다.',
#  '선수의 체력 강화 및 부상 관리 등에정평이 나 있는이지풍 코치 영입이 그 신호탄이다.',
#  '물기가 묻으면 마른 수건으로 살짝 문질러 주듯 닦고 그늘에서 말린다.',
#  '현재 출전이 결정된 팀은 나진 e엠파이어와 삼성 갤럭시, 진에어, CJ 엔투스, IM, KT 롤스터, SKT T1 총 7개 팀이다.',
#  '강풍이 분 탓에 선수들이 대체로 고전했고, 워터 해저드에 여러차례 공을 빠뜨려 난감한 표정을 짓는 선수들이 속출했다.',
#  '그는 며칠 동안 목청을 다듬고 연습에 열중했다.',
#  '처음 보는 물건인지라 청나라 사람은 이상한 지갑도 다 갖고 있구나 하고 총구멍에서 돈 나오기만 기다리고 있는데 총을 쏘고 도망쳐 버렸던 것이다.',
#  '이날 정 의원등 특위소속 의원들은 청주 제17전투비행단을 비롯 육군부사관학교도 잇따라 방문했다.',
#  '선두 KIA는 4월까지 18승8패로 독주했다.',
#  '부모님은 변호사 사무실을 드나들면서도 막상 변호사는 만나보기 힘들었고 대부분의 일은 사무장이 알아서 처리했다.',
#  '공 하나하나에 이제 절박함이 담긴다.',
#  '내가 정말 그날 태어났는지 목격했거나 증언해 줄 사람은 없었다.',
#  '그리고 활하중은 교량을 통행하는 차량이나 보행자에 의해 발생하는 하중으로 가속과 감속, 교면의 요철 등 여러 요인으로 적정 하중보다 큰 하중을 만들어내는 힘이지.',
#  'KBS교향악단과 롯데콘서트홀을 운영하는 롯데문화재단은 2일 오전 11시 잠실 롯데 콘서트홀에서 이 같은 내용을 골자로 하는 상호간 업무 제휴 협약을 체결했다.',
#  '그로 인해 진흥원과 출판계는 많은 대가와 비용을 치르고서야 원점으로 되돌아온 셈이다.',
#  '개인이 300만원을 내면, 기업이 300만원을 부담하고, 정부가 600만원을 지원한다는 건데요.',
#  '그렇기에 지방의 경우 택배보다는 늦게 도착할 수 있지만 더 안전하다는 것이 그의 의견이다.',
#  '반면 다이노나는 2만9250원으로 횡보세를 나타냈으며 케어젠 또한 17만5000원으로 주가 변동이 장을 마감하였다.',
#  '하나은행 수장으로 재직하며 98년 충청은행, 99년 보람은행, 2002년 서울은행을 차례로 인수했다.',
#  '김 내정자는 동아일보 창업자인 인촌 김성수 선생의 손자다.',
#  '그런 나라하고 우리나라는 비교가 될 수 없다.',
#  '또 독버섯은 종류마다 독성분도 다르기 때문에 버섯을 먹고 두통, 구토, 뱃속이 메스꺼움을 느끼게 되면 경험적 치료나 민간요법은 삼가고 즉시 119 등 응급의료기관에 신고하고 반드시 먹었던 버섯을 들고 바로 병원을 찾아야 한다.',
#  '위덕대 김수진 골키파가 승부차기 볼을 손 끝으로 막고 있다.',
#  '19세기 이후 새로운 서구문명의 도전을 받아 온갖 시련과 역경에 봉착했을 때도 항상 자기 혁신의 추구와 함께 넓고도 깊은 자기 확인의 바탕을 슬기롭게 지켜 왔다.',
#  '울리 슈틸리케 감독의 공언대로 선발 명단에 이름을 올린 차두리는 후배들의 배려 속에 주장 완장까지 찼다.',
#  '반면,국고지원금 배정은 2011년 43억8천600만원, 지난해 47억9천200만원에 이어 올해 48억3천200만원으로 소폭 상승하는데 그치면서 3년 연속 중간에 소진됐습니다.',
#  '한편, 중진공 서울동남부지부도 오는 27일 서울 강남구 삼정호텔에서 글로벌퓨처스클럽 추가 결성식을 개최할 예정입니다.',
#  '네오트랜스의 요청을 국토부가 수락해야만 요금 조정이 가능하다는 의미다.',
#  '윤용복 체육성 부국장을 단장으로 하는 북측 선발대가 방남 이틀째인 26일 오전 점심식사를 하기 위해 평창 켄싱턴 호텔에 들어서고 있다.',
#  '강씨는 체육인출신으로는 드물게 지상파 3사에 출연하며 개성 넘치는 카리스마와 진행능력을 인정받아 명실공히 국민 MC라 불리는 등 인기 정점의 고지에 올라와 있다.',
#  '한편 이날 연석회의에선 지난 대선을 객관적으로 평가하기 위해 외부 전문가의 진단을 받아야 한다는 필요성이 제기됐다.',
#  '새로운 시대는 이미 오래 전에 시작했습니다.',
#  '그리고 차두리의 지도력에 환희가 안길 수 있는 가능성도 봤다.',
#  '3일 오전 10시 40분 현재 아시아 주요 반도체주들이 혼조세를 나타내고 있다.',
#  '이들 여러 연구들을 종합하여 볼 때 성적소구광고의 효과는 상황에 따라서 그리고 제품에 따라서 다르게 나타난다고 보는 것이 타당하리라 생각됩니다.',
#  '왼쪽 수비수로 나선 정동호는 허벅지 통증을 호소해 전반 41분 김창수와 교체됐다.',
#  '메이저리그 선수들의 몸값이 천문학적이다 보니 부상 방지에 더 염두를 뒀다.',
#  '평상시 일선 외교관들이 탈북자 보호에 대한 지원이 부족해 무력감에 빠지거나 사명감을 느끼지 못한다면 얘기는 또 달라질 수 있다.',
#  '그들 역시 우리의 친구이자 동행인이다.',
#  '아태평양, 중동 지역에서의 프로젝트 실행 역량을 키워나갈 방침이다.',
#  '그는 젊은 사람들과 소통할 줄 알고, 새로운 생각을 받아들이는 데 노력한다.',
#  '경남 거제에 들어서는 자연생태 테마파크가 윤곽을 드러냈습니다.',
#  '팬에게 부산하면 감동적인 팀이다는 생각을 심어주면 된다.',
#  '유한대 외국어어학센터에서는 원어민 수업이 이뤄진다.',
#  '여성대통령 시대라고 여성을 우대할 필요도 없다.',
#  '분양가상한제는 노무현 정부 시절인 2005년 3월 건설사가 분양가를 높여 기존 집값을 올리고 과도한 이익을 취한다는 비판이 커지자 도입된 제도지만 지금은 시장 상황이 달라진 만큼 수정을 요구하는 목소리가 높다.',
#  '어느 날 문득 그녀가 내 작업실로 전화를 걸어서 우리집에 우리말고 누가 또 사는 것 같애, 하고, 약간 머뭇거리는 듯하면서, 그러나 제법 진지한 어조로 말해왔을 때 내 반응은 그다지 진지하지 못했다.',
#  '그곳에서 내가 집어 낸 것은 고구려 벽화의 힘과 문인화의 여유, 민화의 해학, 기운생동의 운필이다.',
#  '검찰은 또 유씨에게서 금품 로비를 받았다는 의혹이 제기된 배건기 전 청와대 내부감찰팀장에 대해 출국금지 조치를 했다.',
#  '동일 성분에 많게는 100개 이상의 제품이 등장하면서 복제약 시장은 과열 양상을 보였다.',
#  '거기에는 몇 그루 동백나무가 노란 유채꽃들을 융단처럼 바닥에 깐 채 푸른 바다를 배경으로 서서 가지마다 미어터질 듯 꽃을 피워내고 있었다.',
#  '김수남 검찰총장이 구속 수감된 박근혜 전 대통령에 대한 검찰의 구치소 출장 조사를 하루 앞둔 3일 오전 서울 서초구 대검찰청으로 출근을 하고 있다.',
#  '정우택 최고위원은 오늘 국회에서 열린 최고위원회의에서 북한이 입주 기업에 거짓 팩스를 보내 개성공단 파행 책임을 면하고, 남남갈등을 부추기려는 꼼수를 부리고 있다고 말했습니다.',
#  '그러나 아이는 산소 공급과 심폐소생술을 실시했음에도 다시 눈을 뜨지 못하고 뇌사 상태에서 사망했다.',
#  '그리고는 차에 올라앉기가 무섭게 T대학으로 향하게 했다.',
#  '나머지는 적격심사와 수의계약으로 진행되며, 각각 733억원과 3억원이 각각 집행될 예정이다.',
#  '전북은 후반 41분 다시 한 번 코너킥 상황에서 득점에 성공해 추격을 알렸다.',
#  '특히 한파가 이틀 이상 지속되거나 야간이나 외출 시에는 욕조의 수도꼭지를 조금 틀어놓는다.',
#  '1200억원을 투입해 지은 지상18층 지하7층 규모의 건물은 이미 거의 다 지어진 상태였습니다.',
#  '그의 침묵은 홍 박사에 대해 비정스러울 정도로 단호한 부정의 표현이 되었다.',
#  '문화체육관광부는 오늘, 광주시가 지난해 10월에 제출한 유치신청서 내용 가운데, 정부의 재정 보증 서류에 있던 김황식 전 국무총리와 최광식 전 문화체육부장관의 사인을 그대로 복사해 옮긴 사실을 확인했다고 밝혔습니다.',
#  '한편 이날 회의에는 금융위와 국토부를 비롯해 기획재정부, 금융감독원, 한국은행 관계자 및 교수, 연구원 등이 참석했다.',
#  '올해부터 개포주공4단지를 시작으로 1단지와 공무원 아파트 등이 줄줄이 이사행렬에 동참하는 것도 이유다.',
#  '가족회사 정강의 신용카드를 사적 용도로 사용한 혐의 등으로 기소된 우병우 전 청와대 정무수석의 부인 이민정 정강 대표이사의 재판에서 검찰이 이석수 전 특별감찰관을 증인으로 신청했다.',
#  '지금은 아버지의 조언을 따랐던 내 선택에 매우 만족하고 있다.',
#  '고기를 잡으러 나간 강호동, 이규한, 정용호는 연신 올라오는 고기를 낚으며 즐거워했고, 김뢰하는 어머님의 바람이던 평상 고치기에 나섰다.',
#  '올해 출시한 신차라도 해가 바뀌면 자동차 가격이 하락하기 때문이다.',
#  '하지만 새집 싱크대엔 해당 식기세척기 설치가 불가능하다는 통보를 받았습니다.',
#  '또한 인간의 노동은 객관적이고 독립적인 상품 생산 체계의 일부가 된다.',
#  '그는 이후 파 행진을 벌이다 8번홀에서 버디를 낚았다.',
#  '실적 전망치가 상향 조정되고 있는 종목 위주로 관심을 가진다면 추후 충분한 수익을 기대할 수 있는 상황이다.',
#  '한편 외환시장에서 원달러 환율은 1123원을 기록했다.',
#  '또한 2004년 독일의 교육기관과 기업들이 함께 직업교육에 관한 협의서를 채택하면서 본격화되었다.',
#  '1992년 한국 광고 시장은 세계 12위로 공급 포화 상태가 되었다고 발표되었다.',
#  '또, 수제의자 및 테이블, 캠핑전용 전구, 비어치킨용 오븐 등과 같은 DIY캠핑용품 제작 및 사용이 증가하고 있는 것으로 나타났다.',
#  '2회말 선두타자로 나와 유격수 땅볼로 물러난 강정호는 4회에도 같은 방향으로 땅볼을 쳤다.',
#  '뉴우스는 단순히 이 사실 혹은 저 사실, 이 사건 혹은 저 사건을 밝히기만 해서는 안 된다.',
#  '강남구 박순희 부부 유학을 가서 어떤 남자를 만났다면?',
#  '사배자 전형이 부유층 자녀의 입학 통로로 악용되고 있다는 비판에 교육부는 4월 비경제적 대상자 전형에 소득 8분위 이하에 준하는 가정의 자녀만 지원할 수 있도록 제도를 개선했다.',
#  '김 동식 선생님하고 니가 잘 안다는 박 진석씨하고 오셨다 한 시간 전에 갔다.',
#  '지난해 11월 시작된 재판은 수요일을 제외하고 매주 4번씩, 오늘 결심까지 45차례 열렸습니다.',
#  '우즈는 이날 홈런 2개를 터뜨려 150호 홈런을 최소경기 만에 달성했다.',
#  '7일 하늘재 오르는 길에 김연아 나무가 관광객들을 맞고 있다.',
#  '두산이 이번 골든글러브 시상식에서 빈손으로 돌아간다면 3년 연속 구경꾼에 그친다.',
#  '더 나은 결과를 얻기 위해 현실에 안주하지 않고 계속해서 노력해 나가겠다.',
#  'U16 대표팀 출신으로 2008 AFC U16 선수권대회에서 대한민국을 준우승으로 이끈 바 있는 권태안은 2011년 우선지명으로 수원삼성에서 데뷔했다.',
#  '특히 김 씨는 2010년과 2011년 두 차례 정신병으로 병원에 입원까지 했던 것으로 확인됐습니다.',
#  '한편 경기포천경찰서는 이날 베어스타운 스키장 전무이사 장낙진씨와 안전관리담당과장 최성길씨등 2명을 업무상 과실치사상 혐의로 입건, 조사중이다.',
#  '바로 밥집, 고기집, 술집 등을 아울러 가장 인기있는 부산 해운대 센텀 맛집 제주돈가이다.',
#  '전날 일본인 투수 구로다 히로키를 상대로 시즌 20번째 멀티히트를 기록한 추신수는 이날 안타로 타율을 0.275로 유지했다.',
#  '2010년 1조2000억 원을 들여 만든 군산조선소가 7년 만에 가동 중단된 가운데 정부가 군산조선소 재가동을 위한 지원 대책을 마련했다.',
#  '그러나 갑판의 병사들은 바람을 뚫고 빠르게 움직였다.',
#  '체내수분율이 높아지면 피부도 촉촉해지고 피부 온도를 적정하게 유지시켜주는데 도움이 된다.',
#  '이에 외교부는 이번에도 역사적, 지리적, 국제법적으로 명백한 우리 고유의 영토 독도에 대한 일본의 어떠한 도발에 대해서도 단호히 대응해 나갈 것이라는 입장과 함께 해당 내용을 삭제할 것을 요구하고 일본의 영토 도발에 대한 재발 방지를 촉구할 전망이다.',
#  '부처 간, 부처와 업계 간, 업체와 업체 간 목소리가 갈리다 보니 충전기 표준화는 엄두를 내지 못한 탓이다.',
#  '서별관 회의란 과거 국가안전보장회의 등 대북 관련 주요 현안이 논의되던 회의체다.',
#  '런던올림픽 금메달리스트 등 세계적인 선수들이 대거 부산을 찾아 수준 높은 경기를 선보였습니다.',
#  '부정마저 부정했던 파렴치한 아버지의 범죄행위는 법이 징벌할 것이지만 두 딸의 상처입은 몸과 영혼은 어디에서 치유할 수 있을까?',
#  '조 의원은 박 전 대통령이 법정에 오갈 때 바라보거나 자리에서 일어섰지만, 박 전 대통령은 방청석을 응시하지 않으며 별다른 반응을 보이지 않았다.',
#  '창조주인 하나님을 모실 때 우리 70억 인류가 어떻게 나가야 할지 안다.',
#  '복수의 스페인 언론들에 따르면 새롭게 레알 마드리드 사령탑에 부임한 라파엘 베니테스 감독은 호날두를 최전방에 기용할 계획이다.',
#  '소리아 비교 대상이 지동원이었던 것이다.',
#  '정신 차리고 전화 끊으세요.',
#  '따지고 보면 그리 이상할 것도 없는 이야기이다.',
#  '오늘도 전국이 화창한 봄 날씨가 되겠습니다.',
#  '이는 당연히 당 창업주이자 한때 빅3 대선 주자로 평가됐던 안 전 대표 입장에선 불쾌할 수밖에 없다.',
#  '우리 여자대표팀은 지난 2008년 베이징올림픽 예선에서 고배를 마셨다.',
#  '또 한국문학은 과연 어떻게 해야 세계문학으로 떠오를 수 있을 것인가?',
#  '어떤 점을 높이 평가하는지 궁금하다.',
#  '부시와 노무현 대통령을 풍자적 조형물로 묘사한 박건웅씨의 반전조형물도 최근 이라크전 등의 국제정세와 맞물려 보고 느끼는 재미가쏠쏠하다.',
#  '2004년 중국에서 처음 개발된 전자담배는 국내 73개 업체가 수입해 판매하고 있다.',
#  '리버풀과 첼시가 인테르의 스트라이커 이카르디의 영입을 노리고 있다.',
#  '그녀가 남긴 유서는 손가락 길이만도 못하게 짧았다.',
#  '또 이들 회사의 직원인 김모씨는 불구속 기소했다.',
#  '김이 싼 값이었을 때는 겨울의 미각을 즐기며 향수를 맛보았는데, 질끈 눈을 감을 수밖에 없다.',
#  '사진은 진주성에 있는 비석들로서, 왜적과 싸운 훌륭한 조상들을 기리는 것들이 많다.',
#  '사건 무마를 대가로 뒷돈을 챙긴 경찰 간부와 이를 알고 협박해 수천만원을 뜯어낸 60대에게 실형이 선고됐다.',
#  '옐런 의장의 임기는 내년 2월까지지만, 연준 이사 임기는 오는 2024년 1월까지다.',
#  '구글은 지난해 6월 지름 15m 크기의 열기구 30개를 뉴질랜드에서 띄워 인터넷 서비스 제공 실험을 한 바 있다.',
#  '여기에 이용자들을 위해 편의점 세븐일레븐과 제휴 프로모션 및 각종 게임 내 이벤트도 실시하고 있다.',
#  '국정 리더십은 10여 년 전보다 한참 후퇴했다.',
#  '문재인 대통령과 도널드 트럼프 미국 대통령 내외가 7일 오후 청와대 영빈관에서 열린 국빈만찬에서 양국 국민의례를 하고있다.',
#  '산림소득 유통분야 공모사업에 충북도는 2016년도에 가공산업활성화사업 1개소와 2015년도에 산지종합유통센터 1개소가 공모사업에 선정된 바 있다.',
#  '예금보험공사는 각각 7위, 10위에 올랐다.',
#  '울고 있는 큰새의 귀에 마을 사람들의 원망 소리가 크게 들려 왔다.',
#  '이에 시민단체는 국민의 이익을 볼모로 의사의 특권을 보장해 준다고 반발하였다.',
#  '지경부는 전반적인 세계교역감소에도 불구하고 2년연속 수출 달성은 의미가 크다고 설명했다.',
#  '정규 시간이 모두 흐른 후반 47분, 프리킥 기회를 얻은 독일은 나브리의 두 번째 골로 힘겹게 동점을 만들었다.',
#  '사천시는 S골프장이 하천점용 허가 없이 하천수를 무단으로 사용한 것을 확인하고 불법 하천점용 혐의로 지난 16일 사천경찰서에 형사고발했다고 19일 밝혔다.',
#  '그리고 또 한 가지 중요한 것은, 각개 종북 좌파 인사들이 겉으로는 등록금 인하를 주장하면서도 자녀들은 해외에 고액 등록금을 들여 유학 보내는 이율배반적 처신을 하고 있다고 지적하고 있는데 그 밑에 종북 좌파 인사라고 하는 분들이 바로 그 당시 현직 국회의원이었던 권영길, 정동영 의원을 명시적으로 거론하고 있습니다.',
#  '고모, 할머니가 이상하세요.',
#  '송 의원은 공식 출마선언에 앞서 이날 서울 동작구 국립현충원에서 김대중 전 대통령 묘역을 참배한다.',
#  '국민의당 이언주 의원이 1일 오후 광주 서구 염주사거리에서 안철수 19대 대선후보의 지지를 호소하고 있다.',
#  '5차 보고서는 다음 달 23일부터 2014년까지 세 차례에 걸쳐 공개된다.',
#  '지난해 3월 누적판매 15만대를 넘어선 뒤 9개월 만에 추가로 10만대를 더 팔며 누적판매 25만대를 달성한 것입니다.',
#  '공개된 사진은 미국 사우스다코타주 배들랜즈 국립공원에서 촬영된 것으로, 붉은 빛을 띤 바위산 뒤편 하늘을 배경으로 쌍무지개가 떠 있는데 때마침 번개가 쳐서 무지개를 관통한 장면이 포착된 것이다.',
#  '오리온스 치어리더들이 작전타임을 이용 열띤 응원을 펼치고 있다.',
#  '그들 나름대로 납득을 하도록 신경을 써야 한다.',
#  '전달된 수익금은 해당 지역아동센터의 학습 지도 운영비로 사용될 예정이다.',
#  '그러나 로메로는 지난 시즌을 끝으로 삼프도리아와 계약이 만료돼 새로운 팀을 물색하고 있다.',
#  '금감원은 자체 인사윤리위원회를 열어 내부 규정을 위반하고 주식거래를 한 직원을 징계 조치할 계획이라고 밝혔습니다.',
#  '총 수주액 약 20억 달러 중 삼성엔지니어링의 지분은 1조1000억원이다.',
#  '그는 지난 10월25일 외환은행의 대주주인 론스타에 충족명령을 발동했다.',
#  '원주의료기기테크노밸리는 차세대 생명건강 생태계 조성사업을 통해 미래 전략산업인 IoT 빅데이터 플랫폼 활용 기반을 마련하겠다고 26일 밝혔다.',
#  '분기 기준으로 대졸 실업자가 50만 명을 넘어선 건 이번이 처음입니다.',
#  'C조 일본도 한국처럼 죽음의 조를 피했다.',
#  '둘의 각별한 관계가 둥가 감독의 복귀에 힘을 실어줄 것이라는 게 현지의 분석이다.',
#  '하지만 고차원이 무릎을 부여잡고 그라운드에 쓰러졌다.',
#  '두 사람은 문재인 전 대표 체제에서 나란히 지명직 최고위원에 임명됐던 인물이다.',
#  'G마켓, 옥션, 홈플러스, 이마트, 아모레퍼시픽 등 온라인 쇼핑 중 급하게 할인카드를 신청하고 싶은 고객을 위한 서비스다.',
#  '사과 회견 자체도 도마에 올랐다.',
#  '아라파트 수반의 측근들은 그의 경호원 중 최소한 3명이 숨졌다고 전했다.',
#  '종합증명서 발급 시행으로 민원인이 관련 서류를 별도로 떼야하는 불편과 수수료 부담이 줄어들 전망입니다.',
#  '바다의 물결은 동해남부 전해상에서 최고2m로 일겠습니다.',
#  '경계대 등 전 부대원이 개인임무숙달과 협동작전 위주의 해상종합 팀워크 훈련을 반복적으로 실시해 실전과 부합하는 완벽한 전비태세를 갖췄다.',
#  '주커피가 필리핀의 캐세이 철강그룹과 마스터 프랜차이즈 계약을 체결했다고 26일 밝혔다.',
#  '아이코다는 제품 구매 여부와 상관없이 누구나 참여할 수 있으며, 삼성 ODD 구매 후 포토후기를 작성하면 당첨 확률이 높다고 전했다.',
#  '40대 바둑기사는 체력 때문에 젊은 기사를 넘어설 수 없다는 속설을 보기 좋게 깬 것이 바로 조훈현이다.',
#  '고용 안정성의 기준인 정규직 비중이 미미하다.',
#  '팝의 여왕 브리트니 스피어스가 드디어 한국 팬들과 만난다.',
#  '산재를 최소화하기 위한 제도적 해결책 마련도 다짐했다.',
#  '특히 한국은 글로벌 악재 영향으로 코스피 지수가 급락하면서 주식형 펀드에서 큰 폭으로 빠졌다.',
#  '그러나 한림창투의 경우 투자조합의 조기해산으로 3분기 영업이익과 경상이익이 지난 2분기보다 6억4200만원, 2억1100만원씩 늘어 지난 1분기 이후 영업실적이 지속적으로 개선됐다.',
#  '미국에서 뛰었다는 것 자체가 기분 좋다.',
#  '공단처럼 고급천은 아니더라도 해방된 날 고이 간직했던 태극기를 내다건 집이 적지 않았던 개성이 내 고향이라는 게 자랑스럽다.',
#  '특히 유러너스 피디엠 측은 한국인의 정서에 맞춘 편안한 유원시설을 제공하고 더불어 일상에서 느낄 수 없었던 다빈치의 예술, 과학 등의 테마형 경험을 제시하는 스토리텔링화된 관광지로의 구성 목표도 가지고 있다.',
#  '또한 전문가들과 각 분야의전문가들이 참여하는 위원회 구성도 필요할 것으로 본다.',
#  '가슴 한켠으로 뿌듯함이 밀려온다.',
#  '공연주관사 컬쳐뷰에 따르면 JOJ라는 별칭으로 통하는 존스는 10월1일 오후 6시 서울 한남동 블루스퀘어 삼성카드홀에서 한국팬들에게 인사한다.',
#  '미8군은 이 수사를 위해 우리 검찰에 협조를 요청해 공조수사가 진행됐다.',
#  '황재균은 입단식에서 고액에 따른 부담감은 없다고 말했다.',
#  '한편 선진방역형 동물복지농장 사업비는 경기도의회 농정해양위원회를 거친 뒤 예산결산특별위원회 심의를 기다리고 있다.',
#  '경찰은 이날 오후 도주 중이던 용의자 A씨를 전북 임실에서 검거했다.',
#  '찾아서 나오는 낱말보다는 나오지 않는 낱말이 훨씬 많다.',
#  'KBO는 9일 리그 소속선수 등록 현황을 발표했다.',
#  '결국 LG는 9회 말 임훈에게 결승타를 맞고 승리를 가져오지 못했다.',
#  '그러나 덩달이는 여전히 의외의 대답을 한다.',
#  '삼성물산이 준비하는 강남 래미안 포레스트의 분양가가 4500만원 안팎으로 예상되는 이유다.',
#  '서울, 인천 등 전국 6대 도시 버스 노동자들은 임금 인상과 나쁜 근로조건 해결을 해마다 요구하고 있다.',
#  '누군가 남성 작가가 써줬으면 좋겠다고만 생각했는데 누구도 쓰지 않았다.',
#  '구는 2017년도 공동주택지원 심사위원회를 개최하고, 주 관통도로 보수지원사업에 신청한 6개 단지에 대해 사업의 적정성, 효율성, 공공성, 단지 노후도 등을 종합적으로 심사하고 평가 점수가 높은 3개 단지 큰마을아파트, 샘머리2단지, 누리아파트를 선정해 단지별 최대 4천만 원까지 지원하기로 했다.',
#  '총 101개의 공을 던졌고, 스트라이크는 63개를 꽂아 넣었다.',
#  '아이가 어떤 단원이 요구하는 학습목표에 도달했다고 생각해 그 단원의 다른 부분을 가르치지 않고 그냥 넘어가면 학부모들은 교사가 게을러 공부를 시키지 않는다고 여깁니다.',
#  '리샤와 오스트람은 역동적이고 속도감이 있는 씨름의 매력에 엄지 손가락을 치켜세웠다.',
#  'A양은 범행 당일 B양을 데리고 16층인 이 아파트의 13층에서 일부러 내린 뒤 자신의 집이 있는 15층까지 걸어 올라가는 등 치밀하게 범행했다.',
#  '개인 차원이건 국가 등 조직 차원이건 테러는 인류역사와 함께 있어왔다.',
#  '1번 타자로 나선 허경민은 시즌 1호 솔로 홈런을 포함해 2안타 1타점 2득점으로 제 몫을 다했다.',
#  '금융인의 사기와 직업윤리문제를 한번 심각하게 검토해 볼 필요가 있다.',
#  '열매인 솔방울은 황갈색이며, 씨에는 날개가 있다.',
#  '정세균 국회의장이 7일 오전 서울 여의도 국회 본청 계단 앞에서 열린 국회 신성장산업포럼 친환경 자동차 시승행사에 참석해 시승체험을 하고 있다.',
#  '박 전 위원장이 제안한 이산가족 상설면회소 설치와 금강산댐 남북 공동조사 진행에 대해선 즉석에서 수용 의사를 보였다.',
#  '전기용품 형식승인 품목이 대폭 줄어들고 일부 품목의 형식승인 유효기간이 대폭 연장되는 등 관련 제조업체들이 형식승인을 받는데 따른 불편이 크게 덜어진다.',
#  '전신성 관류의 감소 상태가 일어나면, 전신성 관류 압력 이 낮아져 뇌까지 가는 혈류의 감소를 초래하는 수가 있다.',
#  '애리조나에서 허리에 무리가 가지 않는 투구폼으로 바꾸려고 시도를 해봤지만, 마음대로 되지 않았다.',
#  '그때 밖으로부터 그의 동무가 무어라고 떠들며 들어오는 것을 알았다.',
#  '박씨는 빛나고 있는 별들의 아름다움에 취한 듯 아예 머리를 하늘로 향하고 길을 걸어갔다.',
#  '두산밥캣의 23일 종가인 3만3750 원을 적용하면 시장 가치는 3570억 원에 달한다.',
#  '날씨는 싸늘했지만 공기는 대단히 맑았다.',
#  '각 계층 별 약자들을 위한 개혁을 앞세움으로서 약자 계층의 지지를 꾀할 수 있다.',
#  '이번에 발표할 독자 제재에서도 정부는 이들을 명단에 추가하지 않을 방침이라고 한다.',
#  '당시 인터폴에 파견 나간 것 자체가 사이버수사분야에서 한국 경찰의 높은 수준을 보여주는 것이라고 힘주어 말했다.',
#  '최장 6개월까지 학생들에게 시범 테스트해 볼 수 있으며, 시스템 개설비와 사용 학생 숫자만큼의 과금만 납입하면 된다.',
#  '위키리크스의 어산지가 유죄판결을 받고 이곳에 수감된다면 그는 밖으로 나올 수 없을 뿐 컴퓨터로 업무를 처리할 수 있는 셈이다.',
#  '다만, 집주인이 이용하던 대출이 1년 이상 경과되는 등 다른 요건을 충족하는 대출이 돼야 한다.',
#  '공시지원금은 6만원대 요금제 이용시 SK텔레콤 12만4000원, KT 15만원, LG유플러스 15만1000원으로 책정됐다.',
#  '로이킴, 김예림 등 오디션 프로그램 출신들의 음원차트 강세 속에서 존박이 그 바통을 이을 것으로 보인다.',
#  '또래들은 모두 화면 옆으로 걸러나가 누가 보건말건 야무진 오줌들을 갈겨대곤 했지만 지섭은 그럴 수가 없었다.',
#  '그러나 출시 2개월 후 애플이 시리 기술을 2억 달러 이상에 사들이면서 새로운 운명을 맞이했다.',
#  '세나의 하얀 얼굴이 그 소녀의 맨 얼굴 즉 본질이라고 생각하고 있기 때문이다.',
#  '남을 위해 눈물을 흘리는 사람이 진짜 승자라는 거다.',
#  '일하는 사람에게는 칭찬과 핀잔이 상반해야지 칭찬이 많거나 핀잔이 많거나 하면 안 된다.',
#  '수비수인 보스나는 종료 직전 공격에 가담해 슈팅을 때렸고, 공이 상대 수비 맞고 에벨톤C에게 연결돼 결승골에도 기여했다.',
#  '성인 고객 1인당 제공되는 코인 1개를 특별메뉴 중 1개로 교환할 수 있으며, 추가 이용을 원할 경우 추가 비용을 지불하면 된다.',
#  '최근 3년 간 경기도교육청이 교육부 중투위에 승인심사를 의뢰한 학교신설으로 매년 감소하는 추세다.',
#  '상대를 어렵게 만드는 까다로운 볼 스타일도 남다르다.',
#  '이대호는 현역 생활의 마지막을 롯데에서 보내겠단 의지가 강했다.',
#  '국내 LCC 업계의 국제선 운항횟수는 지난해 주 533회에서 올해 주 892회로 크게 늘었다.',
#  '이어 법당 안에서 붓글씨를 쓰며 참선 중인 수상한 두 밥동무를 발견했다.',
#  '연세대는 올해 교무처 산하에 학사관리부를 신설했다.',
#  '도널드 트럼프 대통령 측과 내통설이 나오고 있는 러시아를 압박하는 한편 북한을 상대로 핵무기 포기 선언을 받아내려는 것이다.',
#  '안철수 국민의당 후보와 심상정 정의당 후보는 전교조 법외노조 철회와 합법화 입장이다.',
#  '실제로 판매관리비는 2015년 1억4939만원에서 2016년엔 3억5921만원으로 3억원 이상 급증했다.',
#  '감사원은 지난해 3월부터 한 달간 정부 부처와 지방자치단체, 공기업 등 30곳을 대상으로 공공기관의 불공정 관행 특별점검을 실시한 결과 이같은 내용을 비롯해 총 33건의 감사결과를 시행했다고 12일 밝혔다.',
#  '주로 왼쪽 측면 수비수로 출전하는 김진수는 자신의 앞에 선 측면 공격수와 경기 내내 호흡을 맞춰야 한다.',
#  '물론 나는 심사가 뒤틀려 그때의 상황을 솔개가 병아리 채가듯이라고 표현했지만 틀린 말은 아니었다.',
#  '우리금융지주에 인수된 금호종금이 7거래일째 상승세를 이어가고 있다.',
#  '의미없는 비교가 될지 모르나 인구 비율로 따지면 중국은 한국이 딴 메달의 25배를 따야 하는데 3배에 그치고 있긴 하지만 대단한 스포츠 대국임을 이번에 과시했다.',
#  '그는 이율배반적인 두 가지를 동시에 중요하다고 생각한다.',
#  '공모 교장 심사위원회가 대안교육을 담보할 인적 구성이 이뤄지지 않았다는 것이 교사와 주민들의 주장이다.',
#  '3연패의 상대가 이제 막 프로야구에 발을 들인 NC 다이노스였기에 충격은 두 배로 다가왔다.',
#  '1층 뒤쪽에는 면세품을 직접 살펴볼 수 있는 전시공간을, 2층에는 음료나 주류를 제공하는 두 개의 바를 마련했다.',
#  '지능 지수에 따른 분류의 한 가지.',
#  '2013시즌 메이저리그에 진출한 류현진을 약 1년 4개월 만에 만나는 것이었다.',
#  'FC서울의 제안으로 성사된 이번 협약 기간은 2년이다.',
#  '타이틀대로 카지노를 둘러싼 갱의 내막이 묘사된다.',
#  '국회 농림축산식품해양수산위원회는 이날 오후 국회에서 전체회의를 열고 김영록 농림축산식품부 장관으로부터 AI 발생에 대한 현안보고를 듣고 관련 현황을 질의했다.',
#  '올 시즌 EPL 5위에 그치며 무관에 그쳤던 아스날은 이날 우승으로 아쉬움을 달랬다.',
#  '오랜만에 정치일선에 복귀했으며 과거에도 안면이 있었기 때문이다.',
#  '이러한 이상적인 상태가 표트르 대제로 인해 파괴적이고 강압적인 서구화의 대표적 산물로 생긴 것이 바로 이질적이고 탄압적인 존재로 군림해 있는 니콜라이의 전제정권과 그것을 뒷받침하는 관료 체제였다.',
#  '단, 실적 개선 추세보다 현재 주가 상승 속도가 더 가파르며 현 주가수준 다소 부담스럽게 보고 있습니다.',
#  '대장암은 서구화된 식생활 습관으로 인해 급증한 암으로 평소 올바른 식생활습관과 조기검진만으로도 얼마든지 막을 수 있는 암이기 때문이다.',
#  '또 낮 동안 남부지방에도 강한 소나기가 오는 곳이 있겠습니다.',
#  '경찰 조사 결과 이들로부터 납품 받은 음식점은 양곱창으로 유명한 중구의 A 업소와 해운대구의 B 업소 등 부산시내에만 90곳에 달하는 것으로 밝혀졌다.',
#  '다만 보조기는 장시간 착용하면 주변 근육을 약화시킬 수 있다.',
#  '길 가의 느티나무 밑에서 빨간색 자전거를 잡고 서 있는 미란이의 모습이 나타났다.',
#  '하지만 이보다 더 중요한 건 인터넷을 통해 극장표를 예매하는 새로운 고객군이었다.',
#  '반면, 상하이만 제외한다면 맑은 날씨 이어지겠고, 대부분 30도 안팎을 보이며 덥겠습니다.',
#  '앞서 스탠포드대학 국제안보협력센터의 닉 한센 객원연구원은 지난달 10일 동창리 미사일 발사장에서 진행하는 굴착 작업이 신형 대륙간탄도미사일을 쏘아 올리기 위한 사전 작업으로 보인다고 지적했다.',
#  '경찰은 돈의 사용처와 기부 이유 등을 따져볼 계획입니다.',
#  '내년 3월7일부터 11일까지 모든 팀들이 서로 한번씩 겨루는 방식으로 총 6경기가 열린다.',
#  '지난해 17승6패 평균자책점 3.55의 빼어난 성적을 거둔 장원삼은 시즌을 마치고 자유계약선수 자격을 얻었다.',
#  '공부 시간 외에 틈틈이 부린다면 웬만한 잔심부름쯤은 그애 힘으로도 충분히 해낼 수 있다고 봅니다.',
#  '정미라가 사용하는 장비 이야기를 들으면 한술 더 떠 흥미를 끌게 만든다.',
#  '상오 11시부터 자정까지 계속되는 이 특이한 연주장에 거의 빠지지 않고 스케치북을 들고 나타나는 신동헌화백을 만난 것도 무척 반가운 일이었다.',
#  '초등학생 자녀를 두고 있는 정민석씨는 요즘 고민이 많다.',
#  '박정현은 머리를 땅에 박고 아쉬워했고, 공주고 선수단은 그라운드로 뛰쳐 나와 펄쩍 뛰었다.',
#  '전국적으로 확대되어 나가면서 기독교의 역할이 컸기 때문에 제암리 교회사건 등 기독교측의 희생이 두드러졌으며 선교사들에 대한 탄압도 자행되었다.',
#  '동학군들은 총알을 무릅쓰고 고지를 바라보고 올라갔으나 마침내 쫓긴 바 되어 동편 임록을 의지하여 모여 있던 바 홀연 후면으로서 총소리가 일어나며 수천 명의 군사가 일시에 전사하는지라, 이로부터 동학군은 또 패하여 남으로 궤주하였다.',
#  '그는 공동체와 골목상권을 황폐화하지 않는 상생의 개발을 도심지 주거개선 방향으로 제시했다.',
#  '그리고는 둥글게 몸을 구부렸다.',
#  '즉, 학교 발전의 원동력을 학생 발전에서 찾으려는 통찰과 생각이 부족한 상태이다.',
#  '동의하기도 그렇고 안 하기도 묘하다.',
#  '육군 제55보병사단 조리병 경연대회가 열린 16일 오후 경기 용인 처인구 용인대학교에서 조리병들이 자신들이 직접 만든 음식을 내보이고 있다.',
#  '이로 인해 베네수엘라인들은 지갑 대신 현금이 든 가방을 들고 다니는 일이 일상화됐으며 상인들은 돈을 일일이 세는 대신 저울로 무게를 달기 시작했다고 블룸버그통신은 전했다.',
#  '9회초 7대 4로 경기를 마친 넥센선수들이 자축하고 있다.',
#  '후반기 4강 안정권에 들어갔어도, 선수들의 방심을 막기 위해 채찍질했다.',
#  '결혼하자는 얘기 같은 건 아니겠죠?',
#  '중국과 홍콩 등 중화권 지역의 성장세가 둔화돼 수익성이 하락했으나 아세안은 성장 시장인 태국, 말레이시아, 인도네시아 등에서 고성장세를 유지했다.',
#  '중국과 갈등이 있을 때마다 흔들리는 대만증시에서는 안정적 자본조달이 어렵다고 판단했기 때문이다.',
#  '이에 대해 그는 이렇게 말한다.',
#  '자칫 패할 경우 3위 자리까지 내줄 뻔 했던 현대캐피탈은 5세트까지 가는 접전 끝에 어렵사리 승수쌓기에 성공했다.',
#  '되돌아가는 길도 북한군이 지키고 있었다.',
#  '군검찰단은 4일 입건 이후 6일까지 현장조사, 자료확보 과정을 거쳐 7일 박 대장의 부인, 8일 박 대장을 소환 조사한다.',
#  '한국과 팀 컬러가 비슷하다.',
#  '이어 2012년, 2014년 순이었다.',
#  '기타 자세한 사항은 양주시청소년상담복지센터로 문의하면 된다.',
#  '그 상황에서 텔리프롬프터의 역할은 필수불가결이었을 것이다.',
#  '취약 부분을 집중 공략하는 것도 좋다.',
#  '그리고 이런 사람들은 지금은 비록 어려운 고비를 넘고 있을지라도 언젠가는 반드시 그 꿈을 이루고 마는 것이다.',
#  'EPL이 분데스리가의 질주를 무서워하는 이유다.',
#  '현시점에서는 연평균 6편의 영화를 제작하는 게 MCP의 목표이고, 앞으로 3, 4년 동안에 10억 달러의 제작비를 투자해 25편의 영화를 제작할 예정이다.',
#  '피가로는 지난 2일 넥센전부터 22일 KIA전까지 4경기 연속 승운이 따르지 않았지만 11승 4패 평균자책점 3.29를 기록 중이었다.',
#  '다만 차량 통행은 아직 가능합니다.',
#  '하나님의 말씀에 올바른 사람은 한번 약속한 것은 비록 자기에게 손해가 될지언정 반드시 지킨다고 했습니다.',
#  '특히 한국, 콜롬비아, 파나마와의 자유무역협정 체결 과정에서 중요한 역할을 해온 인물로 알려져 있다.',
#  '타선이 2점을 뽑아준 뒤 보우덴은 한층 안정을 찾았다.',
#  '국회연설을 통해 밝힌 그의 반스탈린주의와 반공산주의선언은 아직도 남아 있는 스탈린주의자의 운명과 그들에게 보내는 엄숙한 경고로 들렸다.',
#  '까스텔로 폰테루톨리는 프랑스 보르도와 더불어 세계적으로 유명한 이탈리아 토스카나 지역의 최고급 수준 와이너리로 알려졌다.',
#  'Walkman형 문화는 생산 체계에서 말했듯이 다양한 문화적 욕구를 소비 대중이 낱낱이 취사 선택해 나가는 방식이다.',
#  '고장 났을 때 제가 하는 서비스를 보고 그 말을 기억해 내십니다.',
#  '새해에 좋은 투자 성과를 거두겠다고 다짐한 투자자들이 많을 것이다.',
#  '류제국은 9월18일 잠실 삼성전에서 9이닝 동안 삼성 타선을 5안타 1볼넷으로 틀어막으며 개인통산 첫 번째 완봉승을 거뒀다.',
#  '모디아노는 1945년 유대계 이탈리아인인 아버지와 배우였던 벨기에 출신 어머니 사이에서 태어났다.',
#  '거래가 부진하던 레이크우드는 문의가 늘어 소폭 상승했다.',
#  '강만수 전 산은금융지주 회장에 이어 전 정권 출신 금융권 수장들이 잇따라 사의를 표명하고 있습니다.',
#  '흙이 패여 나간 곳은 계곡처럼 변했습니다.',
#  '또 미국 정부는 가격을 비롯한 각종 계약 사항에 간여하지 않는다.',
#  '그러나 16번홀에서 어처구니없는 더블보기로 1타 뒤진 공동 4위로 추락해 최대의 위기를 맞았다.',
#  '트럼프 대통령은 후보시절 부터 버락 오바마 대통령이 2015년 시진핑 중국 국가주석을 국빈초청한 사실을 비난하면서 백악관의 국빈 만찬을 깎아내리는 발언을 많이 했다.',
#  '청약일정은 7월 19일 특별공급을 시작으로 21일 일반공급 1순위, 24일 일반공급 2순위 접수를 받는다.',
#  '갤럭시노트7 리퍼폰이 새롭게 만들어지는 만큼 전파인증, 안전성 테스트 등도 이뤄져야 한다.',
#  '의료봉사단은 이번 봉사활동에서 현지 의료 기술로 수술하기 힘든 10여 명의 심장병 아동을 수술할 예정이다.',
#  '본선에 나서는 것만으로도 조별리그 배당금과 월드컵 준비 자금을 국제축구연맹으로부터 받을 수 있기 때문이다.',
#  '물론 그럴 수밖에 없다고 생각한다.',
#  '런스 무료입장이 가능하다.',
#  '2016년 치러지는 수능부터 한국사가 필수 과목이 되기 때문에 사회보다 과학 수업이 일주일에 4시간가량 적다는 겁니다.',
#  '크림생맥주라는 명칭도 김 대표가 직접 만들어 붙였다.',
#  '8일 금융투자협회에 따르면 지난 2일 상장지수펀드를 제외한 국내 주식형펀드에서 886억원이 순유출됐다.',
#  '갑자기 신문기자가 몰려들어 지금 외치는 구호는 무엇이냐, 부르는 노래는 무엇이냐, 어디서 왔느냐는 등 여러 가지를 취재해 가고 플래시가 터졌다.',
#  '공간정보산업은 일자리 창출 등 전후방 효과가 커 신성장동력 업종으로 각광받기도 한다.',
#  '4일과 5일에는 각각 호주, 대만과 맞붙는다.',
#  'SK는 이후에도 박정배와 문승원을 추가로 등판시켰지만 추가 1실점하며 추격 의지를 잃어버렸다.',
#  '반도체 소재기업인 SK머티리얼즈 역시 기대를 받고 있다.',
#  '함께 골프를 친 동료나 캐디와 공모해 홀인원을 했다고 속인 후 보험금을 부당 청구하는 행위가 늘고 있어서다.',
#  '아침과 저녁 사이에는 가벼운 점심, 낮것상이 있었다.',
#  '지난해 12월 전북 정읍에서 홀로 있던 어머니 김환순씨가 집을 나간 뒤 행방불명됐기 때문이다.',
#  '외국어고 중국어과를 졸업하고 경찰대를 나왔다.',
#  '동차와 알리바바는 지난달 31일 자동차 판매와 서비스 분야에서 전략적 협력을 하기로 제휴를 맺었다.',
#  '이날 방송에서는 오랜만에 다시 뭉친 삼형제의 여름 득량도 적응기가 시작됐다.',
#  '이들 두 제품들은 게이밍 환경에 적합한 다양한 특징을 제공하고 있지만, 가장 큰 특징은 144Hz 주사율을 제공하여 여러 게임 환경에서 매끄럽고 부드러운 화면을 제공한다는 점이다.',
#  '경기장을 찾은 1만명에 가까운 현지인들은 경기 시작 1시간 전부터 뜨거운 응원전을 펼쳤다.',
#  '그렇다면 국내 증시가 언제쯤 게걸음 장세에서 벗어날 수 있을까?',
#  '민생 예산에 대한 면밀한 검토와 치밀한 재분배 과정에서 해를 넘겼다면 다른 문제다.',
#  '태권도는 신체를 단련하고 정신을 수양하기 위해 행하던 고유의 무예를 발전시킨 운동입니다.',
#  '코스피가 2000선을 기록하며 약보합세로 마감했다.',
#  '3대 3으로 팽팽히 맞선 11회초 오지환이 오른쪽 담장을 넘기는 결승 투런포를 작렬하며 짜릿한 연장 승리를 거뒀습니다.',
#  '두 수의 차를 빈 칸에 쓰시오.',
#  '곽씨의 친손자인 곽모씨는 2016년 11월부터 지난 3월까지 아버지와 함께 할아버지의 서울 소재 680억원대 부동산에 대한 증여계약서를 위조해 토지등기부등본을 자신의 명의로 이전등기 했다.',
#  '이중 대륙붕 공동개발은 북한측이 88년말 서해 진남포 앞바다에서 경제성이 있는 해저유전을 발견, 개발에 박차를 가하고 있다는 점에서 실현가능성에 한가닥 희망을 갖게 한다.',
#  '운동장과 지하전기실이 물에 잠겨 정상적 교육활동이 불가능해진 청주 운호중학교는 예정일보다 4일 앞당긴 17일부터 조기 방학을 시작했다.',
#  '지난해까지 추념식은 민간차원에서 진행됐지만 올해부터는 정부가 주관하고 있다.',
#  '특히 시내버스 노선을 크게 확충해 대중교통으로 부산 서면권 도심 접근이 보다 쉬워진다.',
#  '그들의 노력은 특히 변화를 부정함으로써 현상 세계를 환상에 불과한 것으로 간주한 엘레아 학파를 극복하려는 데 초점이 있었다.',
#  '연료는 암모니아와 가솔린을 7대 3의 비율로 사용합니다.',
#  '오 의원과 제주도는 지구촌 태권도 가족의 최대 축제인 이번 행사를 국기원과 제주도가 공동 주최함으로써 제주지역이 스포츠산업 메카로 발돋움하고, 국제 관광도시의 이미지를 한 단계 향상 시킬 것으로 기대했다.',
#  '푸르밀은 면역력 강화에 초점을 맞춘 기능성 발효유 엔원의 효능을 부각하기 위해 남재현 의학박사를 모델로 동시에 발탁했다.',
#  '바다 장어의 일종인 붕장어를 대량으로 양식할 수 있는 가능성이 발견됐다.',
#  '이에 대해 교육청은 이런 복합적인 요인이 모두 작용한 때문으로 분석하고 있다.',
#  '시장에서는 또 현대차의 지난해 전체 영업이익이 5조원을 밑돌 것으로 추정하고 있다.',
#  '오봉산 자락에 위치한 만큼 숲 조망과 물금신도시 및 낙동강 조망이 가능하다.',
#  '국방장비과와 항공정비과는 남학생 68명, 여학생 5명을 각각 선발한다.',
#  '이어서 그들은 제주도 여러 곳인 산방굴, 산굼부리, 일출봉, 도깨비도로, 만장굴, 협재굴, 용두암 가 보기와 유람선타기, 말타기 그리고 노래방 가 보기 등 이박삼일을 부지런히 다니고 보고 들었다.',
#  '슬픈 사랑의 약속이 있고 슬픈 이별의 장면이 있는 영화를 보고 싶다.',
#  '도화서 화원이었으나 너무 비속한 그림을 그려 쫓겨난 후 직업화가의 길을 걸었다는 사실이 그의 불운했던 삶을 엿보게 할 뿐이다.',
#  '바지와 스커트는 지퍼를 잠그고 처음부터 끝까지 비슷한 온도의 물에서 세탁한다.',
#  '획득한 이벤트 포인트는 상점에서 인게임 아이템으로 교환 가능하다.',
#  '사소한 이유로 몇 차례 경찰에 체포됐던 전력이 있는 호지킨슨은 주택하자평가사로 일했으며 오래 전부터 공화당을 경멸했던 것으로 알려졌다.',
#  '이번 캠프에는 청소년지도사, 보조교사 등이 캠프도우미로 나서 진행을 도우며 청소년들과 어울리게 된다.',
#  '그건 정말 진실하고 엄숙한 선언이었어.',
#  '그는 더 관심을 두지 않았다.',
#  '다비는 그 눈빛 때문에 그 순간 잠시 클레오파트라의 기분을 이해할 수 있었다.',
#  '계절의 여왕이라더니 5월 날씨란 바로 이런 것이구나 싶게 화창한 날이었다.',
#  '강태욱 수석연구원은 수십 건의 연구 핵심 특허를 보유하고 있으며 민간에 기술을 이전해 사업화에도 기여했다.',
#  '우리 아빠는 종이 아빠라 자전거 밀어주는 일 같은 건 못해요.',
#  '2회초 2사 2루에서 권희동이 좌전 적시 3루타를 작렬해 1점을 만회한 NC는 이어 타석에 들어선 지석훈이 적시타를 때려내 동점을 만들었다.',
#  '1998년 선거 땐 일곱명이 겨뤘다.',
#  '화려한 물감을 탄 컵 안에서 유유히 헤엄을 치는 모습은 생소하면서도 아름답게 보인다.',
#  '가장 재산 손실이 많은 인물은 칠레 구리 광산업체 안토파가스타의 여성 소유주인 이리스 폰트보나였다.',
#  '상 주인공만 맡는 이서진이 예능에서는 당하는 캐릭터가 되니 보는 사람도 기분이 좋았다.',
#  '왼손투수로 좋은 제구력과 마운드에서의 투지가 돋보인다는 평가다.',
#  '공연은 말없이 다가가는 세련된 말 걸기 콘셉트로 마네킹 일루션, 클래식과 마임 현대무용의 콜라보 공연, 마임광대의 서커스 공연, 버블과 마리오네트 공연 등 다양한 프로그램이 진행된다.',
#  '또 시알리스, 바이그라 원료 분말과 쑥 분말, 십전대포탕 등을 섞어 제조해 한방 성기능 개선제라고 속인 것으로 확인됐다.',
#  '대법원의 판결은 결혼을 이성 간 결합으로만 한정한 미국 29개 주의 주 헌법 개정에는 영향을 미치지 못한다.',
#  '3월 중순이라는 이른 시점에 부상을 입은 신광훈은 재활의 시간을 거쳐 지난 7월9일 광주전을 통해 컴백을 알렸다.',
#  '평소 세레나는 다른 선수들에 비해 WTA투어 참가를 많이 하지 않고 그랜드슬램에서 높은 기량을 발휘해 자신의 자리를 유지해왔다.',
#  '만기 전에 해지해 이자를 포기하거나 수수료를 내야 하지만 팻카 시행으로 세금을 내는 것보다 나을 것이라고 판단했다.',
#  '임진왜란 때 소서행장 군이 이 둔지산에 부대를 주둔시킨 것도 이 군량확보를 위해서였다.',
#  '오산시는 지난 12일 한국관광고등학교에서 1인1외국어 지원사업 일본어 원어민 강사를 대상으로 강사 역량강화 교육을 실시하였다고 밝혔다.',
#  '245명 가운데 159명은 한국 주소로 나머지 86명은 홍콩이나 싱가폴 등 해외 주소로 페이퍼 컴퍼니를 세웠습니다.',
#  '분향소가 차려진 제천 실내체육관을 연결해보고 이어서 유족 대표와도 이야기 나눠보겠습니다.',
#  '욕망과 욕망의 변용은 사회의 모든 일에 침투하고, 언어와 문학과 예술에 침투합니다.',
#  '그 마음고생은 미루어 짐작할 뿐이다.',
#  '한편 박근혜 대통령의 국정수행 지지도는 1년 전에 비해 소폭 상승한 것으로 나타났다.',
#  '하지만 구청 측은 일제 점검 결과 뱀을 취급한 흔적을 찾지 못했다고 말합니다.',
#  '권한이 강화된 경찰위원회에 대한 통제 방법으로 국회의 요구가 있을시 위원장이 출석해 보고하는 의무를 뒀다.',
#  '일이 되구 나면 알려 주지.',
#  '당장이라도 여경을 쫓아갈 태세였다.',
#  '따라서 이세돌이 9로 자신의 약점을 먼저 보강한 건 정수다.',
#  '중구은 29일 오전 9시 성안옛길과 입화산 일원에서 제8회 울산중구 입화산 전국 산악자전거 챌린지를 개최했다.',
#  '나는 진심으로 기뻐하면서 A와 정애에게 각각 긴 축하의 편지를 썼었습니다.',
#  'S사는 97년 4월 재미교포 김모씨로부터 나진선봉 지역에 투자조사단을 데리고 가지 않겠느냐는 제의를 받고 업체당 참가비 1천달러씩을 받고 1백개 업체를 모았다.',
#  '1군에서도 필승조는 아니었지만 5경기에 등판해 평균자책점 1.59로 호투했다.',
#  '이곳에는 다양한 컬러의 캐리어 제품이 포함된 트래블 라인과, 기능성을 만족시키는 하드케이스의 백팩 라인, 또 남성 서류가방을 주요 제품으로 하는 비즈니스 라인 등을 갖췄다.',
#  '무대미술가 알렉산드르 쉬시킨과 안무가 니콜라이 레흐토프가 힘을 보탠다.',
#  '군복과 무전기 등을 거래하다 적발되더라도 대부분 경찰 등 수사기관은 교육 후 훈방하고 있다.',
#  '그에게 가장 고통스러운 것 중 하나는 자신에게 남은 시간이 얼마나 되는지를 알 수 없다는 사실이었다.',
#  '뒤를 이어 등판한 신동훈과 우규민, 이상열, 유원상이 모두 호투했지만 타선이 번번이 찬스를 놓치며 점수를 뽑는데 실패, 패배의 쓴 잔을 들이켰다.',
#  '한국대학테니스연맹이 주최하고 양구군과 대한테니스협회, 강원도 테니스협회가 공동 주관하는 이번 연맹전은 남자부 20개교 140명, 여자부 14개교 80명, 임원단 60명까지 총 280명이 대회에 참석하여 단체전과 개인전으로 나뉘어 열띤경합을 벌인다.',
#  '바이러스 질환의 발병 과정에는 자신을 증식시킬 동물 즉 숙주를 찾아 옮겨다니며 계속 바뀌어 가는 무서움이 숨어 있습니다.',
#  '일각에선 카카오가 카카오톡을 활용한 의료 정보 서비스를 출시한다는 관측도나온다.',
#  '멀러리 CEO가 엔저에 불만을 표한 것은 이번이 처음은 아니다.',
#  '사업은 크게 다섯 개 분야로 추진된다.',
#  '갈색여치는 동족까지 먹어치울 정도로 식성이 대단한 해충인데, 거미줄을 제 발로 나올 만큼 천적도 없습니다.',
#  'G9도 내달 2일까지 선물하기 좋은 상품 큐레이션 기획전을 통해 어린이를 위한 선물을 선보인다.',
#  'G20 재무장관과 중앙은행 총재들은 각국의 구조개혁에도 주목했다.',
#  '다만 전년 동기 8700억원의 적자를 기록했던 것과 비교할 때 적자폭은 큰 폭으로 축소됐다.',
#  '먼저 이틀 연속 숨고르기에 들어가며 혼조세를 보이고 있는 중국입니다.',
#  '그 싸움 때문에 지금 우리는 고생을 하고 있는 곳이다.',
#  '잘 아시다시피 한국인 명단은 대행해주는 PTN CTL 내부 고객정보에서 나왔다.',
#  '최 의원은 경선 상대인 안병용 예비후보와 함께 면접장에 들어가서도 공천관리위원들과 화기애애한 분위기를 연출했다.',
#  '그 속에서 우리는 한 경지를 드러내는 서정적 속살과 신선한 무늬의 층위를 만나게 된다.',
#  '업종별로 보면 조선기자재, 자동차부품, 1차금속, 전기전자 등 주요 업종에서 기준치를 밑돌아 경기 부진이 전망된다.',
#  '노후에 자금을 관리하고 잘 소비하도록 돕는 금융권의 지혜가 절실하다는 점을 시사하는 대목이기도 하다.',
#  '8월15일 광복절을 앞두고 전두환 노태우 두 전직 대통령의 사면문제가 사회적 쟁점으로 떠오르고 있다.',
#  '상트페테르부르크, 러시아, 코펜하겐, 덴마크, 스톡홀름, 라트비아의 리가, 헬싱키 등의 대 도시가 그 해안지대에 자리잡았다.',
#  '하지만 올 시즌엔 급격히 구위가 떨어졌고 장기였던 제구마저 흔들리면서 작년의 위력을 잃은 상황이다.',
#  '저녁밥 먹기에 한창이어서 누구 하나 내다보는 사람도 없다.',
#  '손흥민이 하트 세리머니에 대해 해명했다.',
#  '송신영은 1999년 현대에 입단해 12년 넘게 뛰었다.',
#  '김재환은 우중간에 떨어지는 적시타를 때려내며 동점을 만들었다.',
#  '지원센터는 지난 4월 준공 이후 모두 168건의 임상시험과 인증 성과를 거뒀다고 8일 밝혔다.',
#  '나도 모르게 잔소리가 시작된다.',
#  '별도의 신분 확인절차 없이 해당 시설을 이용할 수 있어 입찰자나 재정서비스를 받고자 하는 이용객들의 편의 증대도 기대된다.',
#  '현재 페이스나 구위, 안정감 면에서 팀 내 그를 뛰어 넘는 토종 선발이 없다.',
#  '명품식탁은 연 매출 40억원을 바라보는 5년차 알짜 쇼핑몰로 30대 중반에 창업을 시작했던 이기환 더블피쉬커뮤니케이션즈 대표도 이젠 40대로 접어들었다.',
#  '막바지 작업이 한창인 이 시스템 구축이 완료되면 모든 민원 정보를 공유하고 분석 및 예측이 가능해져 민원서비스가 크게 향상될 것으로 도는 기대하고 있다.',
#  '다양한 혜택으로 투자자들의 부담도 낮췄다.',
#  '그럼 넘친 물을 핥아 목을 축이면 된다.',
#  '두번째로 나를 좋아서 찾아온 일본인은 시와 소설 양쪽을 다 써 내고 있던 고다마란 본명과 청수 무엇이라는 필명을 가진 역시 삼십대의 사내였는데, 그는 내 시보다도 내가 종군하고 와서?',
#  '레스터 시티 돌풍의 선두 주자인 세 선수는 PFA 올해의 선수상을 두고 선의의 경쟁을 벌이게 됐다.',
#  '또는 산소가 없을 때는 어떤 것은 환원되나 생체에서 이러한 반응이 얼마나 효율적으로 이루어지는지는 알 수 없다.',
#  '연기금 등 기관투자가들의 코스닥시장 외면과 저조한 외국인 참여에 셀트리온이 제대로 평가를 받지 못 한다고 본 소액주주들이 카카오 사례를 계기로 행동에 나선 것이다.',
#  '대중경제의 실현에 있어서 근로자 계층은 가장 광범위한 자기 기반과 그들의 새로운 중간층으로서 갖는 성격 때문에 그 역활이 중요시 되는 계층이다.',
#  'LG는 6회말 2사 후 김일경, 최동수의 연속 안타와 정성훈의 볼넷으로 베이스를 모두 채웠다.',
#  '대전 동구는 7일 구청 대회의실에서 대전의료원 동구건립 민간추진위원과 주민들을 초청해 사업추진 설명회를 가졌다.',
#  '더욱 신기한 것은 일 잘하는 20퍼센트 개미만 모아놓아도 또 그중에서 80퍼센트의 노는 개미들이 다시 생겨난다는 이야기이다.',
#  '코트라는 이로 인해 병원에 가지 않아도 멀리 있는 환자의 원격 진료가 가능하고 스마트홈, 교육, 의료, 헬스 등 따로 존재하던 IoT 서비스들이 모두 연결되는 초연결 서비스 시대가 열릴 것으로 전망했다.',
#  '후반과 승부차기를 편집해 방영했다.',
#  '본부의 강경한 태도에 학내 교수들이 중재에 나섰다.',
#  '공급면적에 세대 내 서비스면적이 빠져 있어 실제 사용하는 면적과는 거리가 있다.',
#  '여기서 경쟁력 확보가 절실한 전통시장 상인들과 취업난에 시달리는 청년들에게 안정적 일자리를 제공하는 것이다.',
#  '대여관계에서도 비판하고 견제하되 협력할 것은 적극 협력하는 자세가 필요하다.',
#  '특히 참사 발생 시각인 2014년 4월16일 오전 8시52분부터 완전 침몰 시각인 당일 오전 10시31분까지 1시간30분가량 박 대통령이 모습을 드러내지 않은 점이 명시됐다.',
#  '재산을 의도한 악의적인 행동에 다시금 참담하다.',
#  '지역구에서 성장하고 오래 생활했기 때문에 이곳의 문제점을 누구보다도 잘 알고 있습니다.',
#  '변화나 혁신은 작은 기업에서 잘 일어나기 때문에 이 역시 아이디어의 빠른 상업화에 도움이 됩니다.',
#  '개막 첫날 거리퍼레이드에 서해바다의 수호신인 개양할매와 딸들인 팔선녀가 변산면 참가팀을 이끌며 입장하고 있다.',
#  '이별서약최철주 지음, 기파랑261쪽, 1만2500원 죽음은 두렵고, 불편하고, 우울한 주제다.',
#  '거의 나라에서 다 키워주지 않느냐 그러는데 소득에 따라서 다른지 그렇더라고요.',
#  '정치 체제의 혁명적 교체를 연상케 하는 격동의 파노라마가 과학사에도 펼쳐졌다는 쿤의 증언은 사뭇 우리의 흥미를 끈다.',
#  '이와 함께 여야 대표와 원내대표, 정책위의장이 참여하는 6인 협의체에서 7대 민생과제를 선정해, 그 대안을 국민에게 제시하겠다고 말했다.',
#  '경기 한 시간 전부터 5만 관중이 꽉 들어찬 김일성경기장의 응원은 대단했다.',
#  'KIA는 최희섭과 지난해 연봉 1억5000만원에서 5000만원 깎인 1억원에 도장을 찍었다고 23일 밝혔다.',
#  '안홍철 한국투자공사 사장이 공공펀드 공동투자 협의체 출범식에 참석한 글로벌 연기금 관계자들과 11일 기념 촬영하고 있다.',
#  '한편 현재 넷마블은 세븐나이츠 신규 가입자 전원에게 6성 영웅 선택권을 제공하고 각종 SNS에 길드전 응원 댓글을 남기는 이용자들 중 일정 인원을 뽑아 핫초코 기프티콘을 주는 등의 이벤트도 함께 진행 중에 있다.',
#  '상대를 윽박지르는 강속구를 앞세운 배영수는 리그 최고의 에이스였다.',
#  '한 가지 사실을 두고 두 당사자의 진술이 명백히 엇갈리기 때문에 객관적인 증거 분석 등을 통해서 정확하게 범죄를 파악해야 하기 때문이다.',
#  '지난달 러시아와 평가전에서 연이은 졸전으로 대표팀 쇄신에 대한 목소리가 커졌다.',
#  '소리가 나를 향해 오고 있지 않았다.',
#  '이날 개장식에는 우예종 부산항만공사 사장, 진양현 부산진해경제자유구역청장, 동원그룹 박인구 부회장, 동원산업 이명우 사장, 리차드 릭스 실버베이씨푸드 CEO 등 약 300명의 관계자들이 참석했다.',
#  '우선 극심한 재정적자로 그리스 국채에 대한 신뢰가 무너지면서 국채 금리가 폭등하고, 결국 구제금융을 통해 문제를 봉합했다.',
#  '북한의 계속되는 미사일 도발로 북한에 미온적인 중국에 대한 국제사회의 압박이 거세질 것으로 보인다.',
#  '대림산업은 1994년부터 한국메세나 협의회에 회원사로 가입해, 서울 및 경기지역의 보육원 어린이들을 대상으로 문화 및 예술에 대한 지원을 17년간 지속해오고 있다.',
#  '한 명의 약사가 여러 약국을 동시에 운영하는 법인형 약국을 정부가 허용하기로 했습니다.',
#  '고다드 중학교 등 글렌도라 통합교육구의 5개 학교는 일시 폐교하기로 했다.',
#  '광고 채널 역시 과감하게 공중파를 탈피했다.',
#  '읍내에서 가리왕산자연휴양림까지 하루 일곱 차례 버스가 오간다.',
#  '또 반복적인 전손으로 차량가액의 2.4배에 해당하는 차량 수리비를 보험금으로 챙겼다.',
#  '올해로 4회째를 맞는 이번 행사는 까리따스 방배종합사회복지관과 함께 진행하는 지역사회 나눔 실천 활동으로, 이날은 방배동에 거주하는 어린이 및 주민 400여명과 CJ오쇼핑 임직원 30여명이 참여했다.',
#  '빼놓을 수 없는 것이 인구다.',
#  '우리 사회에서 대학신문은 하나의 당당한 언론이다.',
#  '하지만 펀드매니저의 주관에 따라 움직이는 일반 펀드는 장기적으로는 시장 평균을 따라가기 힘들다.',
#  '권 연구원은 LG이노텍의 주가 상승이 영업성과 대비 미흡하다고 진단했습니다.',
#  '안철수 국민의당 대표가 21일 서울 여의도 국회의원회관에서 제9차 당무위원회의를 마친 후 이동하고 있다.',
#  '다음은 브라질과 크로아티아의 개막전이 열린 지난달 13일 코린치앙스 경기장이었다.',
#  '테이크백으로 가면서 왼쪽 어깨가 올라갔다가, 배팅 순간에는 다시 내려가는 모습이다.',
#  '최 원장의 장례는 행정자치부 장으로 치러지며, 영결식은 12일 오전 8시에 진행된다.',
#  '8인 재판관에 의한 선고가 불법이라는 박 전 대통령측의 주장은 상당한 시간을 할애해 반박에 나섰다.',
#  '가을 야구를 향한 실낱같은 희망도 최정의 글러브가지켜냈다.',
#  '특히 300여 대만 만들어진 이런 수퍼카는 시간이 지날수록 가치가 높아진다.',
#  '비록 중고에서 고물로 한 단계 등급이 낮아진 봉고차일지언정 나는 우아하게 올라타서 천천히 안전벨트를 매었다.',
#  '이에 따라 펌웨어 업데이트를 통해 동영상의 경우 프레임 속도 및 화질 설정에 관계 없이 최장 29분 59초까지 기록할 수 있다.',
#  '전문가들은 공적연금을 확대해 나가면서 중장년층의 일자리를 늘려 이들에 경제 불확실성을 낮춰줄 필요가 있다고 지적합니다.',
#  '2010년 불펜투수로 빅리그에 데뷔한 젠슨은 가능성을 보였고, 2011년 53경기에서 2승 1패 6세이브 평균자책점 2.85의 성적을 남겼다.',
#  '추신수는 7회 2사 후 마지막 타석에서 3루수 앞 기습번트로 멀티히트를 완성했다.',
#  '그러나 공교롭게도 이번 경기에는 4만 명 이상이 올 수 없다.',
#  '결국 이들은 소련의 경제적인 성장은 러시안과 이들 민족지역의 황폐화의 전제 위에서 생성되는 결과로 보기 때문에 이들은 소련의 경제성장 그 자체에 대한 회의적인 입장을 나타내기도 했다.',
#  '이러한 중간 지점이야말로 식민주의의 이데올로기가 피식민인에게 작용하기 시작하는 지점임과 동시에 또한 이데올로기적 저항이 가능한 지점이기도 하다.',
#  '안드레이 키스타 슬로바키아 대통령, 아드리안 하슬러 리히텐슈타인 총리, 달리아 그리바우스카이테 리투아니아 대통령, 케르스티 칼리울라이드 에스토니아대통령, 라이몬즈 베요니스 라트비아 대통령도 방한 명단에 올랐다.',
#  '4일 오후 6시부터 작가와의 대화시간도 마련됐다.',
#  '13차례 선발 등판에서 퀄리티스타트가 8회였다.',
#  '이로써 바르셀로나의 사상 첫2연속챔피언스리그 우승도 물거품이 됐다.',
#  '그리고는 지섭을 혼자 응접실에 남겨 놓고 서둘러 사무실 쪽으로 사라져 들어갔다.',
#  '넥스트무브는 강철의주인의 대규모 업데이트에 맞춰 게임에 접속하기만 해도 풍성한 보상을 제공하는 접속 이벤트와 VIP3 달성 이벤트, 정예 던전 클리어 이벤트, CT 리그 진행 등 다양한 이벤트로 푸짐한 상품을 제공한다.',
#  '여전히 SK에는 김성근 전 감독의 그림자가 짙게 드리워있다.',
#  '어제부터 블랙프라이데이 할인 행사가 시작됐지만 시장 안은 한산합니다.',
#  '지금 국민대중은, 삐딱하게 기울어져 있는데도 넘어지지 않는 피사의 사탑을 보듯이 이 희대의 의혹 덩어리를 지켜보고 있다.',
#  '이에 앞서 14일부터 16일까지 축제를 진행한 백석대 역시 천안시알코올상담센터와 함께 무알콜 축제를 진행했다.',
#  '어제 종가 대비 3원50전이 하락한 1139원 10전에 오늘 거래를 마감했다.',
#  '2001년 이후 가족 등 연고자가 찾아간 유골은 23기에 불과하다.',
#  '그런데 사무실 옆 자리 동료가 씀씀이도 비슷하고 똑같은 카드를 이용하는데도 주유할인은 훨씬 더 많이 받는다는 사실을 알게 됐다.',
#  '이어 SBS는 간접광고 허용시간 위반으로 6000만원, 스카이 라이프티브이는 가상광고 고지위반으로 2000만원의 과태료를 내게 됐다.',
#  '그는 할리우드에서도 인정받는, 한국을 대표하는 배우다.',
#  '이낙연 국무총리가 18일 오전 가뭄피해가 심한 충남 서천군 서면 부사리 김인태씨의 논을 찾아 가뭄피해 어려움을 대해 듣고 위로와 격려하고 있다.',
#  '몇백 년의 풍상을 이겨온 비스듬히 누운 적송을 보며, 우리 민족은 왜 소나무를 기리면서도 소나무의 마음을 닮지 못하느냐는 생각에 잠겨 보기도 했다.',
#  '게임메카는 롤챔스 코리아 2017 스프링 결승전을 앞두고 있는 현장을 찾아 다양한 광경을 카메라에 담아 보았다.',
#  '단디연구소장을 맡았던 공 전 의원은 지난해 9월 경남도당 조직 개편 이후 당직에서 물러나 있었지만 최근 들어 서울시 정책자문특별보좌관, 중앙당 전략기획위원회 부위원장 등을 맡으며 다시 활발한 활동을 전개하고 있다.',
#  '노마는 평소 산수를 잘하는 현수의 목소리를 듣고 여느때보다 더욱 반갑게 맞았다.',
#  '하지만 실제 투자에서 두 지표가 엇갈리는 경우가 적지 않다.',
#  '튀니지에서 시작된 쟈스민 혁명이 시리아까지 도달하긴 했지만, 튀니지나 이집트와 다르게 장기적인 내전으로 치닫고 있는 상황이 시리아가 다른 아랍국가들과 현저하게 다른 상황이라는 것을 말해줄 뿐만 아니라 이는, 아사드 정권이 무너졌을 시 제 2의 이라크가 될 가능성도 배제할 수 없다는 이야기이기도 합니다.',
#  '국 한 가지를 끓이는데도 정말 힘이 들었다.',
#  '놀랍게도 남성은 맨손으로 소를 제압했습니다.',
#  '1997년의 대법원 판결도 같은 내용입니다.',
#  '10가지에 달하는 스마트 필터 효과를 적용하면 효과에 맞는 다양한 연출이 가능하기 때문에 전문 편집 소프트웨어를 거치지 않고도 감성적이거나 재미있는 결과물을 기대할 수 있다.',
#  '동네 지주하 구장집에서 얻어 보는 동아일보 광고란에서 평양 부기 학원 입원생 모집 광고를 보았다.',
#  '그러면 나는 남들 다 보는 것좀 봤기로서니 까짓 무에 대수냐고 응수를 했다.',
#  '안정적이지만 수익률이 낮은 연금보험과 공격적이지만 리스크가 높은 변액유니버셜보험보다 안정성과 수익성을 고루 갖춘 변액연금보험이 지금처럼 불안한 경기에는 훨씬 유리하기 때문일 것이다.',
#  '2014학년도 대학수학능력시험 6월 모의고사에서는 과목별 유형 중 B형이 A형보다 어려웠던 것으로 나타났다.',
#  '들 사이의 합의로 설정이 된다.',
#  '업계 전문가들은 필리핀어학연수는 필리핀전문유학원의 필리핀유학 전문가와의 상담을 통해 학생의 어학능력과 예산, 연수목적 등을 고려하여 최대한 안전한 수속을 할 수 있는 전문 유학원을 선택하는 것이 좋다고 조언한다.',
#  '합병 후에는 신주발행을 통해 화신정공의 발행주식수가 2266만3887주로 늘어나 총 발행주식은 3516만3887주에 합병가액 791억원이 된다.',
#  '영화와 현철은 서로 마주보며 오랫만에 웃어봤으나 그것은 서로를 위로하기 위한 아주 작은 위안의 몸짓이었다.',
#  '실제로 이들이 따라다니는 곳마다 많은 사람들이 따라다녔다.',
#  '몸이 부들부들 떨리거나 심한 허기를 느끼기도 한다.',
#  '너무 힘든 상황이 돼서 미국으로 가게 됐습니다.',
#  '또한 그는 여성운동과 장애인 운동에 적극적으로 참여해왔으며 성소수자를 비롯한 사회적 소수자에 대한 차별 금지 활동에 노력해왔다는 평을 받고 있다.',
#  '기업들은 설비 개선 투자의 필요성을 느끼면서도 석유화학산업의 장기불황 등의 이유로 설비 및 안전에 대한 투자를 꺼리고 있다.',
#  '그러면서도 그녀의 아들이나 큰집 조카인 나한테 집안에 있는 것이면 그것을 아끼는 일 없이 잘도 해먹였다.',
#  '부상 이력과 계약 부담 때문이다.',
#  '그러나 최근 대만이 참치어장에 뛰어들어 대일 수출을 늘리는 바람에 일본에 재고가 쌓이고 어가가 폭락하는 등 고전을 면치 못하고 있다.',
#  '제주특별법 4조는 국세 세목 이양과 제주에서 징수하는 국세 이양을 명시하고 있으나 정부는 다른 지역과 형평성을 이유로 10년째 수용하지 않고 있다.',
#  '검찰은 사이트 분석을 통해 심리정보국 직원 중 일부가 당시 민주당 문재인 대선 후보와 통합진보당 이정희 후보를 비방하는 댓글 수십 건을 올리고 관련 글에 찬반 투표를 한 사실을 확인했다.',
#  '그녀는 얼굴을 찡그린 채 벌판 저쪽 벌거숭이 야산을 바라보았다.',
#  '다른 제조업체에 비해 이익 성장률이 눈에 띄게 높은 것도 이 때문이다.',
#  '그는 한국 인터넷 검색업체와의 협력을 모색 중이다.',
#  '이날 오전 5시45분쯤 김 전 의원이 한강에 투신한 것 같다는 신고가 접수됐다.',
#  '달집 태우기, 부럼 깨기, 부적 찍기, 귀밝이술 체험 행사 등이 대기 중이다.',
#  '별다른 징계를 받지 않은 것은 물론입니다.',
#  '익산폴리텍대학은 관련 산업의 인력 양성을 위한 양질의 교육과정을 개설하고 해당 과정에 대한 지원을 약속했다.',
#  '하루는 그의 부인이 밥과 반찬을 갖추어 남편에게 갖고 와서, 가까이 지내던 사람들을 불러 같이 먹으라고 하였다.',
#  '김현 기자,조소영 기자, 문재인 대통령은 23일 신설된 중소벤처기업부 장관 후보자에 홍종학 전 의원을 내정했다.',
#  '선수의 마음을 헤아리지 못해 자책도 있다.',
#  '화재나 재난 시 병목구간을 빠르게 탈출하려고 하면 무질서가 발생해 오히려 더 늦어진다는 의미다.',
#  '또 며칠연속 하한가를 맞는 종목의 반등을 기대하고 무리하게 투자를 하는 일도 없었다.',
#  '그러나 일본인들은 러시아의 작은 병기들의 사정권 내에 진입하자마자 막대한 피해를 입음으로써 그들의 공격은 맥을 잃었다.',
#  '박씨는 완주의 한 교회 목사로 알려졌으며, 선거를 앞둔 지난 11일 신도들을 동원해 유권자들에게 선교하는 척하며 물티슈와 떡, 차 등을 제공한 혐의를 받고 있다.',
#  '풍선효과가 벌어지고 있다 해서 이를 따라갔다가는 큰 낭패를 볼게 분명하다.',
#  '시위는 이날 오후 시작됐으며 의회 경찰은 의회 내 13군데에서 시위 중단 명령에 따르지 않는 시위대원들을 체포했다.',
#  '이후 기네스 펠트로, 데이빗 베컴, 패리스 힐튼 등 해외 유명 연예인과 스포츠 스타들의 애장품으로 자리매김했다.',
#  '전자담배까지 구입하며 노력했지만 세 달이 지난 지금 결국 금연을 포기했습니다.',
#  '새로운 재료와 이슈에 목말라 하는 현시점에 동사의 이번 재료들이 공개되는 순간이면 모든 것이 끝날 수 있다.',
#  '엔터주 방향성을 예측하기가 어려워지면서 일부 자산운용사 등 기관투자가들은 고민에 빠졌다.',
#  '자칫 허구성이 허황된 초인적인 힘에 의존될 수도 있는 위험을 자연스럽고 리얼하게 극복했습니다.',
#  '조직은 투자금 명목으로 1070만원 상당의 물품을 판매했고 나머지는 합숙비와 생활비로 사용하게 했다.',
#  '4월 미국 소매판매는 예상치를 웃돌며 소비경기 개선 기대를 키우고 있다.',
#  '멍석날 같은 손등으로 입술에 묻은 고구마 진을 훔쳐낸 억순이는 신작로를 가로질러 마을로 들어섰다.',
#  '존 케리 미국 국무장관이 북한이 비핵화에 진정성 있는 자세를 취하면 대화하겠다는 뜻을 밝혔다.',
#  '그리즈만이 다소애매모호한 태도를 보여주며 소문 확산되기도 했다.',
#  '1947년 그런 만주에서 외삼촌이 돌아왔다.',
#  '정부는 여름철 전기절약 행동요령을 평상시 필수요령, 비상시 대응요령, 평상시 권장사항 등으로 구분해 안내하고 있다.',
#  '그러나 롯데는 흔들렸고, SK는 침착했다.',
#  '당시 한국인들이 프란체스카에 대해 얼마나 무지했는지를 단적으로 보여주는 일화다.',
#  '고발에서 사랑으로 부정에서 긍정으로, 분열에서 화해의 미6학으로 바뀌었지요.',
#  '메시는 주급으로 18만 파운드를 받는데 비해 일사는 80파운드를 받는다.',
#  '이어 공개된 각자의 방은 다른 모습이었다.',
#  '우리나라의 국화인 무궁화는 품종 별로 대기오염에 대한 내성이 각기 달라 환경 특성에 맞게 심어야 한다는 연구 결과가 나왔다.',
#  '또 제방이 유실되고 지반 곳곳도 무너져 내려 부실공사 의혹까지 일고 있습니다.',
#  '사향은 의약품으로 분류돼 반드시 식품의약품안전처에 의해 수입이 제한돼 있어 대량으로 구하기 어려운 게 사실이다.',
#  '그리고 장군은 한얼회에서도 몇 손가락 안에 꼽히는 실력자였던 것이다.',
#  '예상했던 대로 부친의 보좌관이 응신했다.',
#  '이에 따라 남성화장품 시장이 급성장하고 있다.',
#  '회견을 통해 금리를 동결하게 된 배경과 더불어 추가 경기부양 계획 등을 설명한다.',
#  '강원랜드 시장형공기업 전환을 놓고 폐광지역 단체들이 거세게 반발하며 대정부 대응 방안 마련에 고심하고 있다.',
#  '이삼 개월 지나고 나서 다시 전화를 거시는 게 어떻겠어요?',
#  '끌려가던 동부는 코버의 3점포와 지미 버틀러의 덩크슛 두 방으로 점수차를 좁혀왔다.',
#  '그리고 나 역시도 그런 생각을 아주 안 한다면 거짓말일 것이다.',
#  '박시영은 후속 정의윤을 뜬공 처리한 뒤, 이재원을 유격수 땅볼로 돌려세우며 추가 실점을 막아냈다.',
#  '우리 기업이 북한에 진출해서 북한의 시장경제를 확산시켜주고 북한에 우리 체제가 더 우월함을 북한 주민에게 알리는 것이기도 하고, 북한을 우리에게 의존하게 만드는 것이다.',
#  'OB 골든라거는 출시 전 시장 조사 단계부터 돌풍을 예고했다.',
#  '이날 붕괴사고는 이날 오전 7시25분께 당고개와 진접을 잇는 진접선 복선전철 제4공구 주곡 2교 하부 개착 구간에서 발생했다.',
#  '새정부 첫 법무부 장관은 조국 청와대 민정수석비서관과 호흡을 맞춰가며 검찰 개혁을 이끌 수 있는 인물 가운데 선정될 것으로 보인다.',
#  '그 뿐만 아니라 만약을 대비해서 구명동의도 철저하게 준비 되어 있었다.',
#  '정부는 법률 1개, 특허 1개, 일반상식 2개 등 총 4개 과제를 선별해 과제당 최대 10억원씩 총 29억원을 지원할 예정이다.',
#  '올해 전자정부 50주년을 맞아 정부는 9월말 전자정부법을 개정하고 11월1일을 전자정부의 날로 지정했다.',
#  '이를 두고 사측이 산재발생 사실을 은폐하려고 한 것 아니냐는 의혹이 일각에서 제기되고 있다.',
#  '만일 여기서 집행위원들의 신임을 얻는다면 오는 9월 IOC 총회를 통해 2020년 정식종목 도입을 확정짓게 된다.',
#  '국민의당 손금주 의원은 한국광해관리공단이 내년부터 덕음폐광 주거지역에 대한 광해방지사업을 추진키로 결정했다고 18일 밝혔다.',
#  '1쿼터 시작부터 조성원의 전담 수비수로 출전한 위성우는 이날 34분을 뛰면서 엘지 공격의 핵인 조성원을 그야말로 꼼짝 못하게 만들었다.',
#  '분당에 있는 삼성SDS의 거점 사무실에서 회사 가상데스크에 접속해 업무를 정리하고 보고하면 하루 일정이 마무리된다.',
#  '도종한 당시 문체부 장관 후보자는 지난 5월 30일 청와대 인선발표 날 의정부교도소에 구속수감된 한명숙 전 총리를 면회했다.',
#  '박 전 대통령은 이날 새벽 298억원대 뇌물을 받은 혐의와 직권남용 권리행사방해, 공무상 비밀누설 등의 혐의로 구속영장이 발부됐다.',
#  '삼성생명 은퇴연구소는 삼성생명 보험연구소 산하 3개 연구소 중 하나다.',
#  '톨스토이는 인간의 착한 심성을 끝없이 설파하면서 정작 자기는 성욕을 주체할 길이 없어 수많은 여자를 괴롭혔고 마르크스도 무산자의 세상을 외치면서 자기 집 가정부한테는 평생 월급 한번 주지 않았고요.',
#  '하게 살 수 있는 방법을 고민했습니다.',
#  '그러던 중 유력한 용의자로 한 남성을 주목, 집중 수사했지만 뚜렷한 증거가 발견되지 않았고 알리바이가 입증 돼 수사는 결국 원점으로 돌아갔다.',
#  '13일 경기까지 김태균이 때려낸 안타 31개 가운데 홈런과 2루타가 각각 4개씩이다.',
#  '이번 대회는 총 2억원의 상금을 수여하며, 벤처캐피탈리스트들로 구성된 심사위원들이 직접 지역으로 찾아가 심사를 한다.',
#  '광명시는 오리 이원익 기념관을 청백리 정신 선양 및 전통문화 전문 교육기관으로 변화시키기 위해 전문 민간운영위탁자를 모집한다.',
#  '홍성흔은 제스처 뒤 씩 웃었다.',
#  '첫째, 공식적 부문의 권위와 부정됨에 따라 이 부문에 대한 불신이 심화되고, 보다 실체적 진실을 담보하고 있는 비공식적 부문에서 유통되는 핵심적 고급정보에 대한 사회적 수요가 창출될 것이다.',
#  'NC 타선의 집중력이 돋보였다.',
#  '삼성전자가 HDD 시장을 본격 대체할 1TB 이상 대용량 SSD 라인업을 공개했다.',
#  '3회 선발 고원준을 내리고 송승준을 투입시키는 초강수를 둔 롯데는 4회말 손아섭의 2루타와 홍성흔의 내야 안타로 무사 1,2루 기회를 잡았다.',
#  '우 전 수석은 처가 재산인 서울 강남구 역삼동 땅을 넥슨과 거래하는 과정에서 넥슨 측으로부터 특혜를 받았다는 의혹, 아들 운전병 특혜 의혹, 가족회사 정강 회삿돈 횡령 의혹, 처가 소유의 차명 부동산을 공직자 재산 신고 때 누락했다는 의혹 등을 받고 있다.',
#  '홍주지명탄생 천년을 맞아 홍주지명 알리기에 한창인 이때, 관내 학생들로 구성된 동아리에서 뜻 깊은 하루를 보내 이목을 끌고 있다.',
#  '2004년 8월 부임한 크리스토퍼 힐 미 대사는 한국에서 공공외교의 테이프를 끊었다.',
#  '이번 첫 LSWC는 한국, 인도네시아, 대만, 태국 선수가 참가했으며 국가별 예선전을 통해 대표팀을 가렸다.',
#  '부상으로 출전하지 못할 줄 알았는데 전북전에 나왔다.',
#  '신연금저축은 연 400만원 한도의 기존 소득공제 혜택을 그대로 유지하면서 납입 한도가 늘어나고 연금 통합 관리와 중도 출금도 가능해졌다.',
#  '이날 선두 삼성이 NC에 패하면서 승리시 1위로 올라설 수 있었던 LG는 한화에 덜미가 잡혀 그대로 2위에 머물렀다.',
#  '광복 후에는 한동안 혼란이 이어졌다.',
#  '기획재정부의 지난 11일 자료에 따르면 3월 담배 판매량은 2억 8000만갑으로 전월 2억 4000만갑보다 4000만갑 증가했다.',
#  '그러니까 연봉으로 치면 500만원 수준이었을 것이다.',
#  '검찰은 그러나 스티커에 담긴 문구만으로는 국가공무원법 위반 혐의를 적용하기 어렵다고 판단했다.',
#  '그러나 합의안이 동예루살렘 문제, 이스라엘군 철수 문제 등을 그대로 남겨두어 반PLO세력의 투쟁명분이 살아있다.',
#  '한편 현 시각 상담이 많은 종목으로는 남해화학, 신흥기계, 네패스, 조일알미늄, 서울식품 등이 있다.',
#  '그런데 드로미오마저도 그를 보더니 감옥으로 데려가던 경관에게서 어떻게 풀려 나왔느냐고 묻고 나서 아드리아나가 빚을 갚으라고 보낸 돈지갑을 그에게 주니 안티포러스는 더욱 어리둥절할 수밖에 없었습니다.',
#  '신청을 원하는 산모는 지원센터에 전화로 상담한 뒤 서비스를 받을 수 있습니다.',
#  '후반 21분 송진형이 문전으로 낮게 올려준 패스를 자일이 오른발로 밀어넣으며 동점골을 만들어냈다.',
#  '김현수는 지난해 12월 볼티모어와 2년 700만 달러 계약을 맺었다.',
#  '조정 대상에는 재산 분할은 포함되지 않았다.',
#  'KBO는 30일 창원시에 신축구장 건립부지 선정과정에 대한 내용 공개 요청 공문을 발송했다.',
#  '손 씨는 충혼탑 주변 및 해반천 정화활동에도 30여 차례 참여했다.',
#  '시설안전공단은 지난 19일 한국서부발전과 재난관리 및 시설점검 분야 기술지원 협약을 체결했다.',
#  '태풍 애그니스가 할퀴고 간 자리마다 엄청난 수해가 있었다.',
#  '서울 양재동 교육문화회관에 2006년 프로야구 신인 지명회의가 열렸다.',
#  '걸을 때는 운동을 한다는 생각으로 남들보다 2배 정도 빨리 걷는다.',
#  '하지만 사형이 선고될 수도 있는 실제 재판에서 다수결로 유무죄를 가르는 것은 부적절하다는 지적이다.',
#  '3년뒤인 2011년 11월 여당 단독으로 국회 본회의를 통과할 당시엔 민주노동당 김선동 의원이 최루탄을 국회 단상에서 터뜨리는 일까지 벌어졌다.',
#  '과연 그렇다면, 전원이 각자 감사하고 있다고 해두고, 세밀한 분석은 그만두기로 할까요?',
#  '이번에 적발된 위조 사실은 지난 4월 말 접수된 제보에 의해서 밝혀져 원전 안전 검증 시스템에 구멍이 뚫렸다는 비판이 커지고 있습니다.',
#  '가입자와 배우자가 모두 사망하면 집을 처분해 돈이 남을 경우 상속인에게 돌려준다.',
#  '그리고 잠시 채 교수는 소파에 양팔을 벌리고 고개를 뒤로 젖혔다.',
#  '필터를 적용해서 확인하고 싶은 관계만 찾아볼 수도 있다.',
#  '다만 업체들이 판매 금지를 어겼을 경우 1회당 5000만원을 지급하도록 한 이씨 측 간접강제 청구는 소 제기 이후 제품이 더 이상 판매되지 않는 점 등에 비춰 받아들이지 않았다.',
#  '22개 은행으로부터 3억8000만 달러에 달하는 신디케이트론을 일으키는 방식으로 자금 조달을 했습니다.',
#  '차기 대선 유력주자였던 안 의원 역시 정치적인 상처를 입고, 현재까지 조용한 행보를 이어가고 있다.',
#  '촛불과 향을 밝히고 사루어 두 부부가 수없이 절을 하며 치성을 드리는데 오색실로 부부의 엄지손가락 좌우를 묶어 서로 연결해서 기도가 끝날 때까지 풀지 않는다.',
#  '중국 국민들의 일본에 대한 감정도 급속히 나빠져 왔다.',
#  '잠시라도 짜증을 냈던 내가 한없이 부끄러워지기도 했다.',
#  '그렇다고 자세와 스타일만 생각해서 옷을 얇게 입고 나갔다가는 혹한기 날씨에 몸이 얼어 안정감 있는 플레이를 펼칠 수 없다.',
#  '2차전 상대 기니는 아프리카 예선에서 3위로 통과했다.',
#  '대개의 여자들은 귓바퀴 앞쪽보다 뒤쪽에 더 많은 성감대가 있는 법인데 수혜의 경우는 그 반대이다.',
#  '그는 화장을 못 하는 여성들이 쉽게 따라할 수 있는 메이크업 팁을 알려줄 계획이다.',
#  '대선 당시 선대위 상황실 부실장을 맡은 조 전 위원은 이씨로부터 지난달 24일 처음 조작 사실을 들은 인물이다.',
#  '말리커피는 이달 중 RTD 병음료 제품을 출시한다.',
#  '대원들은 격리상태에서 외상 후 스트레스 장애 조사도 받았다.',
#  '기상청은 다음 달에도 평년과 비슷한 기온을 나타내다가 일시적으로 한파가 몰아치겠지만, 이번처럼 춥진 않겠다고 전망했습니다.',
#  '지식인에 대한 감시를 조금도 늦추려 하지 않는다.',
#  '한국도로공사는 2010년 4월1일부터 사용이 중지된 고속도로 카드의 잔액을 국민들이 제때 환불받을 수 있도록 오는 16일부터 6월말까지 집중 홍보기간으로 정하고 대국민 홍보에 나선다고 밝혔다.',
#  '잎은 알꼴인데 보통 깃털 모양으로 다섯 갈래 깊게 갈라진다.',
#  '정용진 신세계 부회장, 우영택 고양시의회 부의장이 24일 오전 스타필드 고양점에서 오픈 세레머니에 참석해 테이프 커팅을하고 있다.',
#  '세월이 약이라는 말은 이 준엄한 진실을 받아들이는, 일련의 지극히 고통스럽고 잔인한 과정을 일컫는다.',
#  '실내공기질 조사는 어린이집 2000여개소를 대상으로 전수조사가 실시되고 있으며, 조사항목은 실내공기질 오염지표 항목인 총부유세균, 아토피 등 환경성질환 유발물질로 알려진 폼알데하이드다.',
#  '인간이 사물을 효용에 따라 가치를 매기고, 의미를 부여하는 것이 편견일 수 있음을 드러낸 글이다.',
#  '기러기가 울며 날아오는 찬서리 가을인데도, 불볕이 타고 있다는 월남에서, 무돌이는 알록달록 색동처럼 테를 두른 편지를 보내 왔습니다.',
#  '또 한국당 의원들은 전날 대검찰청과 방송통신위원회를 방문한 데 이어 이날 고용노동부와 청와대를 항의 방문할 예정이다.',
#  '4회 두 번째 타석에선 범타로 물러났으나 6회초 세 번째 타석에서 1타점 2루타를 때려냈다.',
#  'CJ사건을 목도한 그룹들이 일감 개방으로 정부와 코드를 맞추고 있다면 식품업체들은 박근혜 대통령이 4대악이라고 표현한 불량식품 단속에 심혈을 기울이고 있다.',
#  '채용 자격 등은 전남도 및 전남학숙 누리집에서 확인할 수 있다.',
#  '자치단체의 세입증대를 위해 공공요금의 무더기 인상이 예상되기 때문이다.',
#  '그러다가 그는 자신과 동명 이인인 어느 중학교 교장의 부음을 읽었다.',
#  '그렇다고 현실 세계와 가깝다는 건 아니다.',
#  '둥근 보름달이 지다 말고 수평선에 걸려 파도 따라 마치 조각배처럼 두둥실 떠다니던 날 밤을 꼬박 새우며 새벽까지 양승을 했는데 그날은 최고로 큰 고기를 낚았고 어획량도 많았다.',
#  '새 천년에 국민들이 희망을 갖기 위해서는 정치개혁이 이뤄져야 한다.',
#  '아쉽게 본선대회에 출전하지 못한 학생들은 관전하며, 자신의 학급 친구가 한 문제 한 문제를 풀어갈 때마다 더욱더 열띤 응원과 박수를 보내주었다.',
#  '물가 상승률을 감안한 임금이 전년보다 줄었다는 얘기다.',
#  '문 위원장은 강연에서 노사정의 사회적 대화와 타협의 중요성을 강조했다.',
#  '아직 쓰이지 않은 책에 대한 판권 게약이다.',
#  '소설은 운동이라는 대의 속에 숨겨져 왔던 청춘들의 방황과 불안, 아픔을 상세히 조명한다.',
#  '김민휘는 끝내 18번홀의 악몽을 털어내지 못했다.',
#  '그러면서 계획대로 8월 말 수색을 마치는 게 어려워질 가능성도 제기되고 있습니다.',
#  '다른팀과 구체적인 협상까지 오갔지만 세부 조율이 이뤄지지 않아 트레이드는 성상되지 않았다.',
#  '올해로 3회째를 맞은 사랑의 푸드 위크는 시민들이 참여해 손수 요리를 만들어 나눠먹고 양로원에 기부도 하는 행사다.',
#  '풍계리 핵실험장은 지난 2006년 이후 5차례에 걸쳐 핵실험이 실시된 곳으로, 한미 정보당국은 북한이 언제든 추가 핵실험을 할 수 있는 상황이라고 경고해 왔다.',
#  'MVP 에릭 테임즈가 142경기를 책임진 NC 1루는 RC 기준 무려 173점을 생산했다.',
#  '그러나 북한이 괌을 향해 ICBM을 발사하면 미국이 대응공격에 나서기 때문에 괌과 다소 떨어진 해상으로 쏠 것으로 예상된다.',
#  '국제 비영리 언론단체인 언론인보호위원회는 지난 9일 성명을 통해 북한의 언론인 추방 행태를 강하게 비판했다.',
#  '도요타는 1997년 12월 세계 최초로 양산형 YV 프리우스의 초대 모델을 론칭했다.',
#  '그러자 올해 초 환경부는 각 자치구에 독립채산제 폐지를 권고하는 공문을 보냈으며, 최근에는 서울시에서 청소대행 제도개선팀을 구성하고 연구용역을 추진하는 등 제도 개선 움직임을 보인다.',
#  '그토록 굳게 닫혀만 있던 어머니의 방문이 스르륵 열린다.',
#  '그런데 정치권이 최근 이를 법에 명문화하려 하면서 논란이 일고 있습니다.',
#  '어느날 갑자기 사람들은 세상을 전혀 다르게 바라봅니다.',
#  '그다음에 정말 어떻게 하는 것이 우리 국익을 위한 것인지 아니면 우리 국익을 차치하고서라도 얻어야 할 인류 보편적인 가치와 우리나라의 비전이 무엇인지에 대한 신중하고도 냉철한 분석이 필요하다는 점을 재차 강조하고 싶다.',
#  '그가 진지하게 대답했으므로 내 질문도 진지했을 거예요.',
#  '개별적으로 추진되고 있는 에너지원별 가격정책을 통합적 관점에서 조정, 합리적인 에너지 소비를 유도하겠다는거다.',
#  '그 무관심이 수해피해를 엄청나게 키운 셈이다.',
#  '이번 사고에서 선장과 항해사, 조타수, 기관사 등 선박 운항과 승객 안전을 책임진 선원 15명은 모두 생존했습니다.',
#  '쌀은 이 시기에 이르러 주곡으로 자리잡으면서 그 수요가 크게 늘었다.',
#  'SK 와이번스 이만수을 각각 선발로 예고했다.',
#  '경쟁사 설비 트러블, 허리케인 영향 등에 따른 기초유분 스프레드 확대와 PVC, ABS 등 다운스트림 부문의 실적 호조가 실적을 이끌었다.',
#  '여기에 회사채가 1조8500억원, 기업어음이 1조1200억원으로 모두 더하면 20조원 수준이다.',
#  '동생 C씨도 지난 2월 우울증 증상 등으로 치료를 받던 중 스스로 목숨을 끊으려 시도하다 경찰에 의해 구조됐다.',
#  '3통은 원래 타이완 정부에 대한 압박수단으로 오래 전부터 북경정부가 요구해 온 것이다.',
#  '구조조정펀드도 나오고 벤처펀드도 나온다.',
#  '물론 여전히 테이퍼링이 조기 실시되기 힘들 것이라는 주장도 존재한다.',
#  '아울러 롯데월드타워는 현장 방문이 어려운 사람들을 위해 불꽃쇼 당일 페이스북을 통해 생중계할 예정이다.',
#  '우리 군 최고 지휘관이 미얀마를 방문한 것은 1983년 아웅산 폭탄 테러 당시 이기백 합참의장 이후 32년 만에 처음입니다.',
#  '신속한 수사를 위해서라는 게 이유였습니다.',
#  '대형마트 이마트가 1993년 1호점을 선보인 지 24년 만인 올해 처음으로 신규 점포를 내지 않는 것으로 알려졌다.',
#  '미국쪽은 이와 함께 지난 6월 서울 용산의 미8군기지에서 아파치 헬기를, 8월 한미합동 포커스렌즈훈련 때는 수원 공군기지에서 패트리엇 미사일을 공개하는 등 이들 무기의 국내 선전활동을 벌여 왔다.',
#  '셔터글라스 방식의 3D 기능을 채택했으며, 800만 화소로 일반 TV보다 4배 이상 선명한 화질을 제공한다.',
#  '게다가 그처럼 문제의 한 면만이 아니라 양 면을 보는 사고가 힘없는 지식인들의 서재담론의 차원에서가 아니라 힘을 가진 권력엘리트의 정책천명의 차원에서 드러나고 있다는 사실에 나는 희망을 갖게 된 것이다.',
#  '특히 청주시는 뉴욕 한인경제인협회와 수출 지원 협약을 체결해 뉴욕한인경제인협회가 청주시 기업인협의회 회원사의 미국 수출을 위한 바이어 발굴 및 연계 지원, 시 기업인협의회와 뉴욕 한인경제인협회가 계획하는 사업에 대한 지원, 기타 당사자 간 합의가 이뤄진 사업 분야에 대해 적극적으로 지원하기로 했다.',
#  '국내에서 생산되는 물건이 있어야 국영 상점에서 판매가 될 수 있다.',
#  '앞서 김 제1위원장이 후계자 시절이던 2011년 7월 김정일 국방위원장과 함께 이 공장과 농장을 현지지도한 바 있다.',
#  '이에 따라 OK캐쉬백 포인트로 결제가 가능해졌다.',
#  '비행 시 문제가 생겨 강이나 바다에 불시착해도 카본 섬유 소재라 항공기가 물에 뜨게 된다는 설명이다.',
#  '결국, 운명의 굴레에 속박된 며느리의 고통을 지켜보며 같은 여자로서 깊은 동정심을 느끼게 된 어슈는, 왕황에게 돈자로부터 멀리 떠나 재혼할 것을 권유한다.',
#  '그렇다고 해서, 발전의 가치 함의에 대한 의견이 완전한 일치가 이루어졌다는 말은 아니다.',
#  '가담 정도가 가벼워 불구속 기소된 남편 김모씨에게는 징역 2년6개월에 집행유예 4년을 선고하고, 사회봉사 120시간을 명령했다.',
#  '그러다보니 최근엔 간편하게 진행할 수 있는 저축은행 중에서도 햇살론 승인률높은곳이 어디인지 이슈가 되고 있다.',
#  '후반 25분 마타와 영을 빼고 야누자이와 디 마리아를 투입했다.',
#  '그러므로 우리의 이상은 예상이나 가상이나 계획이나 욕구가 아니고, 사실은 미래의 역사다.',
#  '채무자가 채무를 조정 후 법원이 허가한 변제계획에 따라 채권자에게 분할변제를 하고 5년 이내 계획된 기간 내 일정 금액을 변제할 경우 남은 채무를 면책 받을 수 있도록 한 것이다.',
#  '본래 새들에게만 감염되었던 조류 인플루엔자가 사람에게 전염되는 것도 그런 변형 때문이니까요.',
#  '청와대는 다만 남북 정상회담 시기에 대해 조심스러운 입장을 보이고 있다.',
#  '모비스는 양동근이 광저우 아시안게임 대표팀에 차출된 뒤 1승 8패로 한없이 추락했다.',
#  '그런데도 지금 무분별한 수입과 엄청난 부동산매입, 증권 물타기에 따른 차익챙기기등 때문에 사회적 비난을 받고 있다.',
#  '의미들은, 탈이나 우상으로 존재하는 의미들은, 높은 곳에도 있는 것이 아닌가?',
#  '코나아이가 해외 시장 진출에 힘입어 지속적인 성장세를 보일 것으로 전망됐다.',
#  '내가 풋, 하고 웃자 현피디가 왜?',
#  '주민들이나 낚시꾼들이나 이런 분들의 증언들이 하나같이 예전에 보지 못하던 현상이 있기 때문에 이러한 것도 중요한 근거가 된다고 생각을 하고요.',
#  '팀 내에서 수비가 가장 약한 채태인는 김현수의 타구를 연속 호수비했다.',
#  '이미 늦가을 해는 기울어 땅거미가 짙어진다.',
#  '올해 1월부터 10월말까지 전국의 출생신고는 34만9558명, 사망신고는 23만1203명으로 자연적 인구 변동은 11만8355명 증가했다.',
#  '석유화학, 자동차, 조선산업의 비약적인 발전과 더불어 국내 최대 산업항으로 중요한 역할을 해왔습니다.',
#  '하지만 고속도로 1차선에서 30초 넘게 멈춰서면서 자칫 더 큰 2차 사고로 이어질 수도 있었던 아찔한 순간이었다.',
#  '웃다가 서방질한다는 말은 맞는 말인 것 같다.',
#  '유거브는 조사에 참여한 사람들은 4개의 그룹을 분류했다.',
#  '늘 솔직한 말로 결혼을 기다리고 있음을 표현했다.',
#  '다 3회말 공격에서 1타점 적시타까지 날린 터라 관중의 함성은 컸다.',
#  '이렇게 화살을 던져 통에 집어넣어 가장 많은 점수를 확보한 팀이 승리하는 방식입니다.',
#  '두 팀 선발 투수는 7회도 실점 없이 막아냈다.',
#  '이와 함께 농심은 문제를 제기한 특약점에 대해 일체의 보복행위나 불이익을 주는 어떤 행위도 하지 않겠다고 약속했다.',
#  '당신이 내 말을 고분고분 들으면 다시 공항으로 와서 셔어먼에게 핸드백을 받아 비디오 테이프를 드리겠어요!',
#  '곧바로 한국 초청이 결정됐다.',
#  '특히 그 원장님은 괜찮은 헤어숍이 있으면 몇 달씩 파견을 보내주셨어요.',
#  '그녀는 옷도 갈아입지 않은 채였다.',
#  '한 업체의 소개자 추천서에는 한 사람당 30개 이상의 개인 정보가 적혀 있었다.',
#  '더불어 이날 우승으로 페데러는 ATP투어 통산 95승을 기록하며 역대 2위 기록을 달성했다.',
#  '볼보이에서 같은 꿈을 꾸는 동료가 됐다.',
#  '7월 한달 간 모바일11번가를 이용한 고객이라면 누구나 누적금액과 구매횟수에 따라 최대 1GB까지 데이터를 보상받을 수 있다.',
#  '따라서 본고의 서술도 뚜렷한 체계나 통일성이 없이 보고된 조사자료를 인용할 수밖에 없을 것 같다.',
#  '박찬호는 단체훈련이 끝난 뒤에도 필요한 시간을 꼭 빼낸다.',
#  '중남미 지역에서 일고 있는 개혁은 국내문제에 한정되서 이루어지는 것이 아니라 국제적인 변화와 맥락을 같이하고 있다.',
#  '물끄러미 구멍가게를 바라보고 눈물을 흘려 보았자 될 일이 아니었다.',
#  '그 문제에 대해 상당히 안타깝고요.',
#  '한국당 원전대책특위는 정부여당이 사용후 핵연료 논란까지 더해 탈원전 이슈 띄우기에 나서자, 이에 대한 반격 차원에서 이번 토론회를 열었다.',
#  '남구는 올해부터 찾아가는 무료법률 상담과 맞춤형 복지팀 운영안내, 복지상담 부스를 추가로 운영한다.',
#  '모두 관심을 거둘 수 없는 선수들이지만 가장 눈여겨 볼 선수는 메이저리그 진출을 꿈꾸고 있는 윤석민이다.',
#  '코리아 쌀베지 작업자들이 28일 오전 거치된 전남 신항만에 거치된 세월호에서 수색 작업을 펼치고 있다.',
#  '프랑스에서는 비위사실이 중대하고 형법에 위반되는 경우에만 제한적으로 처분한다.',
#  '하멜의 보고서는 알 수 없는 경로로 유출돼 유럽 전역으로 팔려 나가며 베스트셀러가 됐다.',
#  '김무성 대표와 박근혜 전 대표가 표면으로 사이가 벌어졌던 이유도 세종시 수정 논란에서 출발했을 정도다.',
#  '색다른 카자흐스탄 문화의 전통예술공연을 통해 우리의 전통예술공연과는 다른 색다름과 세계의 문화적 다양성을 함께 공유하고 공감할 수 있는 기회다.',
#  '동자승이 땅을 조심조심 파헤치며 대꾸했다.',
#  '문체부는 이 같은 올해 관광 진흥 유공 포상계획을 수립하고 각계로부터 관광산업 발전에 기여한 인사들을 추천받는다고 16일 밝혔다.',
#  '부당한 해고에 반발하며 20년에 걸친 올림푸스의 분식회계를 폭로했던 그는 3월 주주총회에서 사장직에 복귀할 기회를 노려왔다.',
#  '한국장학재단은 14일 2017년 1학기 2차 신청자 중 소득구간이 산정된 대상자에게 소득구간 결과를 한국장학재단 홈페이지에 발표했다.',
#  '저스틴 에드워즈가 13득점 6리바운드로 힘을 더했다.',
#  '이제는 암울했던 밤의 이야기를 하지 맙시다.',
#  '합격자는 28일 개별 통보된다.',
#  '국내 신용평가사들의 실적이 감소세를 이어가고 있다.',
#  '젊은층은 말할 것도 없고, 설화를 생활의 일부로 삼아 왔던 향촌의 노인층조차도 텔레비젼이나 화투 등으로 소일하고 있는 상황이다.',
#  '한편 대화동은 앞으로도 학교폭력예방, 아동학대예방 등 다양한 주제로 생활복지 마을 강단을 실시할 계획이다.',
#  '게다가 이놈의 개는 도무지 애완견다운 귀염성이라곤 눈꼽만큼도 없었다.',
#  '평소 운동량이 적었던 김씨는 많은 양의 운동을 갑작스럽게 하자 약간의 근육통으로 평소보다 피곤함을 느꼈다.',
#  '부산 해운대구의 비즈니스호텔이 탄핵 가결을 자축하는 객실 무료 이벤트를 벌이고 있다.',
#  '특히 잉글랜드 프리미어리그에는 월드컵 출전 선수 중 6분의 1이 몸담고 있는 것으로 조사됐다.',
#  '문 대통령이 대선후보 시절부터 강조해온 한반도 신 경제지도와 연계된 신북방정책도 이번 방러를 통해 제시될 계획이다.',
#  '박지성이만 막다보면 다른 공간에 구멍이 나므로 다른 선수들도 잘 막겠다.',
#  '2차로를 달리던 A씨는 해당 차량을 피하려고 1차로로 진입했다가 뒤에서 오던 고속버스 앞쪽 우측면을 들이받았다.',
#  '그리고 임부총리가 IMF 다 해결됐다고 그랬는데 그러나 임부총리는 대통령께서 에이펙에 가야한다고 강력하게 주장을 했습니다.',
#  '시교육청은 교육부에서 먼저 정규직 전환 심의위 대상 직종에 대한 가이드라인을 내려줘야 기관 단위에서 기구를 만들 수 있다는 입장이다.',
#  '각기 다른 분야의 인프라를 가진 캐피탈사의 시너지 효과를 기대한 결정이다.',
#  '이후 2016년 10월 단 1차례 정식운행도 하지 못한 차량 10량과 궤도를 모두 철거했다.',
#  '올 출시한 3세대 버블 세탁기의 거품 기능을 더 향상시켰다.',
#  '우원식 더불어민주당 원내대표가 13일 오전 서울 영등포구 여의도 국회 더불어민주당 원내대표회의실을 예방한 김성태 자유한국당 신임 원내대표단과 인사를 나누고 있다.',
#  ...]

# %% [markdown]
# ---
# # Preprocessing
# ---

# %%
def extract_word(text):
  text = text.lower() # 소문자 변환
  convert = re.compile('^\d*\d$|[^가-힣a-zA-Z0-9.ㅋㅜㅎㅠ]') # 해당 문자만 남기고 나머지 제거
  result = convert.sub(' ',text) # 변환

  result = re.sub(r'[" "]+', " ",result) # 공백 여러개를 한개로 변환
  result = result.strip() # 양쪽 공백 제거

  return result

# %%
for i in range(len(data)):
  data[i] = extract_word(data[i])

# %%
with open('/content/drive/MyDrive/2.Study/BERT/stopwords.txt', 'r', encoding = 'utf-8') as f:
  stopword_list = []
  value = f.readlines()
  for i in value:
    stopword_list.append(i.strip())

stopword_list[:4]
# Out:
# ['가', '가까스로', '가령', '각']

# %% [markdown]
# ---
# # Morphological analysis
# ---

# %%
# !python -m spacy download ko_core_news_lg
import spacy
nlp = spacy.load('ko_core_news_lg')
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-23 07:43:31.405154: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-23 07:43:32.643678: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-23 07:43:32.643812: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-23 07:43:32.643834: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-03-23 07:43:34.445378: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ko-core-news-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ko_core_news_lg-3.5.0/ko_core_news_lg-3.5.0-py3-none-any.whl (230.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.9/230.9 MB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.9/dist-packages (from ko-core-news-lg==3.5.0) (3.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (2.0.8)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (1.22.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (1.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (2.0.7)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (0.7.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (1.0.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (2.4.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (1.1.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (23.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (6.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (8.1.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (2.27.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (3.0.12)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (67.6.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (1.0.9)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.9/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->ko-core-news-lg==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('ko_core_news_lg')
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
def tokenizer(text):
    doc = nlp(text)

    vlaue = []
    # 토큰의 정규화된 형태소
    texts_list = [token.lemma_.split('+') for token in doc]
    # 토큰의 형태소 태그
    tags_list = [token.tag_.split('+') for token in doc]

    for token_idx in range(len(doc)):
        if tags_list[token_idx][0] in ('ncn','ncpa','ncps','nc','nq','f'):
        # 현재 토큰의 정규화된 형태서와 형태소 태그의 개수가 동일하다면 
            if len(texts_list[token_idx]) == len(tags_list[token_idx]):
                vlaue
                if tags_list[token_idx][0].startswith('n') or tags_list[token_idx][0].startswith('f'):
                    vlaue.append(''.join([text for tag,text in zip(tags_list[token_idx], texts_list[token_idx]) if tag in ('ncn','ncpa','ncps','nc','nq','f')]))
                else:
                    vlaue.append(texts_list[token_idx][0] + '다')
            elif tags_list[token_idx][0] in ('ncn','ncpa','ncps','nc','f'):
                vlaue.append(texts_list[token_idx][0])
            else:
                vlaue.append(''.join((texts_list[token_idx])).replace(' ','_'))

    return vlaue

# %%
# BOW 생성
vectorizer = TfidfVectorizer(tokenizer = tokenizer, min_df = 2, ngram_range = (1,1), stop_words = stopword_list)

# %%
vectorizer.fit(data)
vectorizer.vocabulary_

# %% [markdown]
# ---
# # BERTopic
# ---

# %%
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic[visualization]
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 KB 4.1 MB/s eta 0:00:00
# WARNING: bertopic 0.14.1 does not provide the extra 'visualization'
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 47.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (5.13.1)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.22.4)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (4.65.0)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.4.4)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic[visualization]) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.1.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (0.29.33)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.27.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.14.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.13.3)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (67.6.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.39.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic[visualization]) (1.16.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.13.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (8.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.26.15)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3582115 sha256=867d11a6e4613f12ed78219ccd1e3b27d7fbe6de7908b29d69345a67f20df0bd
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=abf5a046e384c641ccc5454c2e132f426d4cb0bbbd725b290371398e01d96643
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82830 sha256=0297021c82fa64b161b6e2554cc029021785ae8deea069999130be09b087cc44
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55509 sha256=59235bcbece4b6a45d12ac3cfb656c94ed0257ece3cd55b14895eec49eb60c8b
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: sentencepiece, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 pynndescent-0.5.8 sentence-transformers-2.2.2 sentencepiece-0.1.97 umap-learn-0.5.3

# %%
from bertopic import BERTopic
from umap import UMAP
import hdbscan

# %% [markdown]
# ---
# ### UMAP
# ---

# %% [markdown]
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcIJ0Jd%2FbtrxrbQB0YD%2FqF4Am3Y4DFvFTEBvIN6vHK%2Fimg.png'><img src = 'https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FYNnw2%2FbtrxAa3tHdy%2FbfnSWgdePxJNhgkGi5A1vk%2Fimg.png'>

# %% [markdown]
# - PCA와 비슷한 차원 축소 알고리즘
#
#     - PCA의 경우 maxtirx factorization이고
#
# - UMAP은 neighbor graph를 기반의 비선형 차원축소 기법
#
#     - 고차원 데이터셋을 이해하고 시각화하는 툴
#
#     - t-SNE와 비슷하나 속도도 더 빠르고, 데이터의 global 구조를 더 잘 보존함
# - 즉, 데이터가 실제로 존재하는 n차원의 그래프를 더 낮은 차원의 비슷한 그래프로 축소시키는 것
#
# - 일반적으로 클러스터링 알고리즘은 고차원의 공간에서 클러스트링을 수행하는데 어려움을 겪기 때문에
#
# - UMAP을 통해 임베딩의 local 및 global strcture를 보존하면서 차원을 축소

# %%
'''n_neighbor = 이웃한 데이터 포인트의 수를 나타내는 파리미터, 일반적으로 작을수록 고차원의 데이터를 잘 표현

   min_dist = 최소 거리를 나타내는 파라미터, 작을수록 저차원 공간에서의 데이터 간 거리가 더 유지

   n_components = 차원 축소 후 저차원 공간의 차원 수를 지정하는 파라미터, 일반적으로 2차원 혹은 3차원으로 시각화 하는데 사용

   metric = 거리 측정 방법을 지정하는 파라미터, 유클리드, 멘하턴, 코사인 등등

   n_epoch = 최적화 과정에서 반복 횟수를 지정, 크면 정확한 변환 결과를 얻지만 계산 비용 증가

   learning_rate = 학습률, 클수록 더 큰 변환을 얻음'''

umap_model = UMAP(n_neighbors= 15, min_dist = 0.1, n_components = 5, random_state = 415, metric = 'euclidean')

# %% [markdown]
# ---
# ### hdbscan
# ---

# %% [markdown]
# <img src='https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FcSBFNR%2Fbtrxrbwkcud%2FctVHPNTlow5YD2MtKk8Pi0%2Fimg.jpg'>

# %% [markdown]
# - 밀도 기반 공간 군집화 기법 중 하나로 DBSCAN과 유사하지만, 밀도 기반 클러스터링 기법을 더욱 효과적으로 처리하도록 개선된 버전
#
# - 축소된 임베딩을 HDBSCAN을 사용해 outlier를 식별하고 클러스터링
#
# - 고차원의 nested clusters를 효과적으로 분류하기 위한 알고리즘
#
# - 핵심 개념은 Mininum Spanning Tree(MST)로 거리 매트릭스를 기반으로 MST를 구성하고 군집을 구성하구 위해 MST를 잘라내는 방식
#
# - MST에서 각 포인트에 대한 최소연결 거리를 계산하면 클러스터링 결과를 얻을 수 있게 되며, 가우시안 혼합 모델을 사용하여 클러스터를 분리하는 방법을 적용
#
# - HDBSCAN의 이점은 자동 클러스터 크기 결정과 높은 노이즈 저항성
#
# [HDBSCAN 설명](https://heave.tistory.com/60)

# %%
'''min_cluster_size = 클러스터를 형성하는데 필요한 최소 포인트 수 설정, 클수록 더 밀집된 클러스터 생성

   metirc = 데이터 포인트 사이의 거리를 측정하는데 사용할 거리 메트릭

   cluster_selection_method = HDBSCAN에 의해 생성된 계층적 클러스터 트리에서 클러스터의 최종세트를 선택하기 위한 기준을 지정
      2가지 주요 옵션은 eom(질량 초과)와 leaf로 
      eom 방법은 총 데이터 질량의 지정된 백분율을 캡처하는데 필요한 계층 구조의 최소 수준을 기반으로 클러스터를 선택
      leaf 방법은 최소 포인트 수가 있는 계층 구조의 최하위 수준을 기준으로 클러스터를 선택 

   predict_data = 훈련된 모델을 기반으로 기존 클러스터에 새 데이터 포인트를 할당, 전체 모델을 재교육하지 않고 새 데이터 포인트의 클러스터 구성원을 예측하는데 유용

   min_samples = 그래프를 작성할때 고려할 가장 가까운 이웃의 수를 설정, 커질수록 포인트 간의 연결이 더많아지고 더 많은 클러스터가 연결될 수 있지만 시간이 늘어나게 됨

   Alpha = 클러스터 밀도와 클러스터 수 사이의 균형을 제어, 커질수록 클러스터가 점점 더 작아지며 대부분 기본값 1.0이면 충분

   Bandwidth = 밀도 추정에 사용되는 커널의 너비를 제어, 커질수록 밀도 추정치가 더 부드러워지고 연결된 클러스터가 더 많아지게 됨

   Leaf_size = 리프 노드 크기를 제어, 커질수록 클러스터링 시간이 빨라지지만 품질이 낮아지게됨'''
hdbscan_model = hdbscan.HDBSCAN(min_cluster_size = 10, metric = 'euclidean', cluster_selection_method = 'eom', prediction_data = True)

# %%
model = BERTopic(embedding_model = 'sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens',
                 vectorizer_model = vectorizer,
                 top_n_words = 15,
                 min_topic_size = 10,
                 umap_model = umap_model,
                 hdbscan_model = hdbscan_model,
                 verbose = True)

# %%
topics, probs = model.fit_transform(data)
# Out:
# Batches:   0%|          | 0/125 [00:00<?, ?it/s]
# 2023-03-23 10:02:13,753 - BERTopic - Transformed documents to Embeddings
# 2023-03-23 10:02:41,627 - BERTopic - Reduced dimensionality
# 2023-03-23 10:02:42,071 - BERTopic - Clustered reduced embeddings

# %%
# 토픽의 개수, 토픽의 크기, 각 토픽에 할당된 단어
# -1의 값은 토픽에 포함되지 않는 문서
model.get_topic_info()
# Out:
#     Topic  Count                Name
# 0      -1   2428       -1_경찰_전_한국_검찰
# 1       0    283        0_수술_말_장애인_꿈
# 2       1    275       1_소리_사람_여자_부정
# 3       2    157      2_올해_증가_상승_지난해
# 4       3    122        3_대출_은행_주가_돈
# 5       4    121       4_대구_서울_교수_대전
# 6       5    120       5_타자_안타_시즌_타석
# 7       6     80      6_일치_베트남_효과_건강
# 8       7     51       7_학교_학습_수업_참여
# 9       8     38        8_숲_세목_유치_공동
# 10      9     37      9_게임_인터넷_구매_제공
# 11     10     32      10_부진_초반_넥센_실수
# 12     11     29      11_김_불교계_지진_버스
# 13     12     27     12_불필요_설비_민원_업종
# 14     13     24     13_대통령_북한_비판_대북
# 15     14     24    14_비_남부지방_고기압_예년
# 16     15     23     15_진행_이벤트_시작_매주
# 17     16     21    16_투자자_자동차_투자_산업
# 18     17     21      17_국회_서울_오전_참석
# 19     18     20  18_우승_대회_바르셀로나_올림픽
# 20     19     17     19_몸_c조_오름세_평가다
# 21     20     15      20_스타_유럽_인기_현역
# 22     21     13      21_손바닥_기분_맛_고추
# 23     22     12        22_말_화_웃음_장난
# 24     23     10    23_광화문_프로젝_성분_구호

# %%
model.get_topic(10)
# Out:
# [('부진', 0.09636612258442384),
#  ('초반', 0.08554432761531158),
#  ('넥센', 0.0726637147087419),
#  ('실수', 0.06711326011105447),
#  ('경기', 0.06703052749797436),
#  ('최악', 0.061081672322790215),
#  ('통증', 0.059341411739098994),
#  ('구단', 0.05354663221621141),
#  ('패배', 0.052193560515890684),
#  ('lg', 0.05139840597766953),
#  ('호소', 0.04705965804121242),
#  ('내년', 0.0456944337251392),
#  ('선발', 0.04510294063787924),
#  ('시즌', 0.04343423235221933),
#  ('이후', 0.03707351289368887)]
